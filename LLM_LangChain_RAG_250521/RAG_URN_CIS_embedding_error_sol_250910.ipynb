# %%
# CIS 및 URN 관련 논문 요약하기 (250905)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma

# %%
# 디렉토리 내 모든 파일을 리스트로 변환하는 함수 정의

import os

def list_files(directory):
    file_list = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_list.append(os.path.join(root, file))
    return file_list

# 지정된 디렉토리 내 모든 파일명을 리스트로 호출
file_names = list_files('./data')
print(file_names)
# Out:
# ['./data\\constitution_of_Korea.pdf', './data\\doc_CIS_URN_250903.pdf']

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
# 버전 문제 해결 : https://chan7ee.tistory.com/entry/issue-tensorflow-keras-transformer-%EB%B2%84%EC%A0%84-%EB%AC%B8%EC%A0%9C
# pip install tf-keras==2.16.0

# 문장을 임베딩으로 변환하고 벡터 저장소에 저장
embeddings_model = HuggingFaceEmbeddings(
    model_name='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',    # 다국어 모델
    # model_name='jhgan/ko-sroberta-multitask',  # 한국어 모델 - 에러 발생 (250603)
    # model_name = 'BAAI/bge-m3',                # 에러 발생 (250603)
    model_kwargs={'device':'cpu'},
    encode_kwargs={'normalize_embeddings':True},
)

embeddings_model
# Out:
# C:\Users\wonta\AppData\Local\Temp\ipykernel_15212\881631784.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings_model = HuggingFaceEmbeddings(
# WARNING:tensorflow:From c:\Users\wonta\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
# ), model_name='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2', cache_folder=None, model_kwargs={'device': 'cpu'}, encode_kwargs={'normalize_embeddings': True}, multi_process=False, show_progress=False)

# %%
loader = PyMuPDFLoader(file_names[1])       # 폴더 내 파일 1개만 존재 : 여러 개일 경우, 최초 1개 DB 생성 후, Add 방식으로 진행 (250605)
documents = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100) 
docs = text_splitter.split_documents(documents)

# 임베딩 DB 생성 : 파일로 저장하지 않으므로, 새로 실행할 경우 초기화됨 (250605)
db = Chroma.from_documents(
    documents=docs, embedding=embeddings_model, collection_name="db_URN_CIS"
)

# %%
# 파일로 DB 저장하기

from langchain.vectorstores import Chroma

# 'store_db' 경로 생성
vectorstore_path = 'store_db'
os.makedirs(vectorstore_path, exist_ok=True)

# 벡터 저장소 생성 및 저장
store_db = Chroma.from_documents(docs, embeddings_model, persist_directory=vectorstore_path, collection_name="db_URN_CIS_250905")

# 벡터스토어 데이터를 디스크에 저장
store_db.persist()

print("Vector created and persisted.")
# Out:
# Vector created and persisted.
# C:\Users\wonta\AppData\Local\Temp\ipykernel_23536\1364977411.py:13: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   store_db.persist()

# %%
# 폴더에 여러 개의 pdf 파일이 있는 경우, 
# 데이터베이스 추가하기 : 폴더 내부의 파일 전체를 DB 처리

'''
for i in range(len(file_names)-1):
    loader = PyMuPDFLoader(file_names[i+1])
    pages_new = loader.load_and_split(text_splitter)
    _ = store_db.add_documents(pages_new)

'''
# 파일에 추가 : 코드를 중복으로 실행하는 경우, 동일한 내용 중복 입력 주의 (250602)
# Out:
# '\nfor i in range(len(file_names)-1):\n    loader = PyMuPDFLoader(file_names[i+1])\n    pages_new = loader.load_and_split(text_splitter)\n    _ = store_db.add_documents(pages_new)\n\n'

# %%
# 파일로 저장된 DB 불러오기
vectorstore_path = 'store_db'

store_db_load = Chroma(
    persist_directory=vectorstore_path,
   # embedding_function=HuggingFaceEmbeddings(),
    embedding_function=embeddings_model,           # 임베딩 모델을 다르게 설정하여(모델별 벡터 차원이 다름) 발생한 문제
    collection_name="db_URN_CIS_250905",
)

# %%
''' (250905 해결)
지금 코드에서는 Chroma.from_documents(..., embedding=embeddings_model)로 384차원을 사용했습니다.

그런데 similarity_search를 실행할 때는 768차원 임베딩 모델이 들어간 Chroma 인스턴스를 사용했기 때문에 dimension mismatch 발생.

해결 방법
1. 같은 임베딩 모델로 로드하기

DB를 불러올 때도 **반드시 같은 모델(384차원)**을 지정하세요.

# persist_directory 지정 후 저장
db = Chroma.from_documents(
    documents=docs,
    embedding=embeddings_model,
    persist_directory="./chroma_db",
    collection_name="db_URN_CIS"
)
db.persist()

# 불러올 때도 같은 embedding_function 사용
store_db_load = Chroma(
    persist_directory="./chroma_db",
    embedding_function=embeddings_model,
    collection_name="db_URN_CIS"
)

2. 매번 새로 만들 경우 (persist 안 쓸 때)

db 객체 자체를 바로 사용하면 dimension mismatch가 일어나지 않습니다.

searchDocs = db.similarity_search("CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)", k=10)
print(searchDocs[0].page_content)


요약

지금 에러는 DB를 만들 때 사용한 임베딩 모델(384차원)과 검색할 때 쓰는 임베딩 모델(768차원)이 달라서 발생

해결책:

DB 저장(persist_directory) 후, 같은 임베딩 모델로 다시 로드해서 사용

혹은 persist 없이 db 객체를 바로 사용
'''

# %%
# 내용 확인

store_db_load.get()
# Out:
# {'ids': ['ddaf75f4-0c28-4837-9ace-f6b98704a344',
#   '6570b0d7-0046-41bf-af07-a21fe54fb7c8',
#   '696562dd-8d41-4dfd-aae1-1a96c2cb67e8',
#   'a9c33bf1-7fa7-41b6-a423-2f3da44b9dc3',
#   '43a6ed9e-f12e-4843-8f82-933dd3031748',
#   'ea30d7f8-67c6-4172-969f-e99bc1a57e25',
#   '53ea9d77-0324-4d23-ba33-bcc4f511b296',
#   'bd8ac3f9-15b4-4140-87a3-dd63dc7a248f',
#   '662c6c63-feb8-4a21-ae28-713e72c1429f',
#   '29dc6ec4-dae0-4194-8828-b1ce047c4973',
#   '633606bc-9f5c-4f00-8179-0087d26fc41a',
#   '454fae71-bb13-4409-9bb1-fc293f3c6edd',
#   '4ce15a9e-3a6b-4eb7-a8fe-d09ef228c1ea',
#   'e85c0c4b-ded3-4466-b4b1-47aa051bc4e4',
#   'fc834014-ff42-4985-9eff-6e1d4681c4ca',
#   '9acb5feb-5bd7-4837-9f2c-fde7d48fa67a',
#   '690c933c-0f74-4d3d-92ca-54ee48e01794',
#   'ed16be46-69fb-40b8-9941-23cddbf595b7',
#   'bf95a3e3-9479-4829-ab21-72624cc2e974',
#   '2d129c6b-f243-414d-ba34-0d42d3cfe6a2',
#   '2208bd57-adb2-4569-a05b-ed5a27829580',
#   '711e87d0-860c-4038-a13a-b309e587e1d3',
#   'd1070016-4ffa-4a48-b8cc-5b04595bc933',
#   'cbdfde39-7c4a-40eb-b4bc-721558860daf',
#   '1eb2ef78-eb84-4159-9710-15ac00c82241',
#   'febca5f8-060e-4520-8193-24f17704804a',
#   'f1883821-4a42-483f-8b7f-9cdc317fd89f',
#   '5add3f6a-b672-480f-9600-0104ca2dfb51',
#   '76d95dc0-7e8f-43e7-b02b-115a01bee7e7',
#   'cffe1682-6f5d-4b83-a41a-a823a71a515d',
#   'c22353f4-38ab-4aa5-a74c-59703f7d9793',
#   '88194b42-b4d0-4aa7-94f8-0da07fa5dc8e',
#   '2a2645bd-f182-466d-9e37-46d4c0deb8b5',
#   'f55c1f62-b821-44bc-935d-3b63617bfe57',
#   'aaa7f87a-6a54-4066-91bf-85f66704a452',
#   '893b075e-7f47-489a-8eec-65193043cd86',
#   'd9820883-47c6-40d9-8f89-c112f85039f2',
#   '80883266-f46b-4364-817d-686d31a1d5d0',
#   '86f89146-4c22-4166-a3e0-0e6f48d80f2a',
#   '9a01f032-b78f-4b68-ab8b-4efa20c0b97e',
#   'fdacd2e6-f0ea-4139-8ae9-483ffc334679',
#   'db4fdf03-83c6-47c5-8691-c6d419379534',
#   '70b2e2cb-854f-4e53-82b5-46a25fbf4a07',
#   '5952bd2c-7781-46b3-9014-4492f51ae52a',
#   'f943570e-c028-4975-b052-b55daa13b647',
#   '0817b22b-7593-4a6c-9b82-4f1171a24e82',
#   '29ea38a2-bd1d-427d-8353-e3b6e748e732',
#   'bfa797f0-814a-4942-a3cf-ae10e495068d',
#   '7f8ebecc-348a-40fa-8ee2-e25bfaaa8aab',
#   '1abe5fa5-1b04-4e6f-92dc-95b07f1336b5',
#   '93b99a8f-c34a-4ce8-bf3b-17cc8a6aa7f3',
#   '3f5f5117-6246-4c85-84c6-5b5e0d8c8e59',
#   'a07d6120-53d9-4edc-9769-b1ae13af6c82',
#   '2269a71b-a9a2-45c4-aa99-9d3e041183de',
#   '6353046d-1158-459f-91b2-ad79e73cba6e',
#   '1c308654-9239-489d-a7e2-4ab611bd8df8',
#   'def78c20-33e8-4eb0-965b-1cbba855ad8a',
#   'a554358d-c547-410a-aac9-383ee8d09698',
#   '53a4f00f-4ce6-4f9c-a60c-866d80472d3a',
#   '8ef6aab2-7f79-48e0-9683-3a5f8ae26630',
#   '5fc4e745-ef3a-4e2f-a66c-b62d55457828',
#   'f2b33569-85ec-4e27-84e8-c4dba1a7fa3b',
#   '6e6b7edc-dd9f-4c52-b5d0-d7ef46e7bc92',
#   '29ac5f02-b27d-4e75-8b9b-21b0b76e8b7c',
#   '3e2b584e-944a-43e3-a9da-c3b80ce74a2e',
#   '507b6823-e1d3-4280-a88c-35424a2e38a2',
#   '04eea7f2-13a7-4418-98f9-46e97876ab46',
#   'e18f7e91-eeba-4346-86fb-e53b4362ebd7',
#   '6af1806e-f71f-4536-a950-89ad07a8870f',
#   '75d49490-fa7d-435e-9ef2-1f1813ec71be',
#   '15b916e3-f342-47c3-a379-9b2be2c8cc02',
#   'b1b99bd6-87b5-4b16-ab93-69fdd6d99fe7',
#   'c8f55b79-e012-4173-bb1b-8f93ff2ede8f',
#   'c3147d62-b7e8-4015-8448-1e246d31dd02',
#   '3a7e5aca-a793-4956-a8c5-04b6543e7f6b',
#   '68f188f6-4aa7-47fd-821f-0f1cceb72d68',
#   'f9a35ee4-2c50-4551-b7f6-fff3412da193',
#   '8e1bc6b2-ff77-4563-ad7c-9d7a3bc2bd0e',
#   '81ad2425-b1bf-43d8-97ae-0d9ad83ebd7e',
#   'd0d9a713-c124-449d-af85-d9220786c9f2',
#   'de20b605-ab67-4d67-b03c-122e5b628242',
#   'e4286b65-95f5-4b92-bc68-d45ea2af13d9',
#   '85bf7961-ddbb-4545-af5d-10deda47421d',
#   '09d04375-a528-4cc5-8aa9-a44b77a40dd0',
#   '9ca9a74f-a977-4892-b64c-7ed951b6627f',
#   'c52c6757-3c66-4c3d-826b-303c07cb0cb2',
#   'fe3088ed-b255-4020-88ca-c0443a0ebc50',
#   '15d1a8ac-54c8-40fe-9496-593b9cb87fa8',
#   '0a3ea0c2-184a-4049-bf8c-0aa3b8bd5e0b',
#   '716fb4e3-ae56-447a-8c93-0d1a91b0d300',
#   '6bea7344-e99b-4b1c-ae27-9365b3309ae2',
#   '5fed547b-d568-4a2f-8cd0-b5e530348719',
#   '0d797e56-6f22-4691-b20a-7a4116b8d6bc',
#   '67a66e9f-5f1e-4a07-811d-d5225f3ae623',
#   '6ad75f28-40bd-4324-a012-b63ad40572b8',
#   '86519f45-3e56-4f4a-adf0-6b98dcbef832',
#   'b18f3328-101c-4526-a1d2-d0aa360205f5',
#   '8dc8c57f-9e61-499c-a403-e24454dc811f',
#   '4851d968-d453-4204-96cb-0cf60765d171',
#   '98abe052-4cdc-4b0c-bd32-cb78f2259fa4',
#   '971dfbc2-a3eb-47c0-9d61-35452fcca2f0',
#   'bb0c2d05-1c41-49f9-8b60-6c1ecdffa3ae',
#   'b9bc3c97-1213-4b45-8470-7a5c2fe5bbf1',
#   '909f3eaa-a178-40a1-a83d-2d5e4f692e77',
#   '2e6b1d91-e802-4941-b474-da18fa2b8fdd',
#   '9ad319e9-a2ea-4539-a493-c2a50d263a91',
#   '75adbd59-fb8e-42a0-a07e-3eb528750694',
#   '9196f34b-a38e-4192-9ee1-58ddbf49b111',
#   '3cd6d71c-7997-4c55-b61c-6dadd617c949',
#   'f04ddbf9-9192-480c-9f65-489463a36cd6',
#   'd9d728ad-f67f-4b47-bdeb-1a7b95c524a3',
#   '76df096e-7688-4690-87f0-002dd7871aa7',
#   '58d79b76-7086-4970-99a1-9961a301ef1d',
#   '6a686114-5e4c-424d-9fa6-27e2bd333257',
#   '23267508-8e65-471d-a685-eb3e274b0eae',
#   'e8b6157f-e878-4609-b2a9-4e30d9756c5e',
#   'a0cceb3f-49e6-4e60-8b3a-89758bd09941',
#   'b39b8994-1100-47ee-94e8-04c9c2323658',
#   'ec8b8a36-a38f-4bc2-b145-850a8ada1c29',
#   'f654e7eb-ed42-4463-b420-26ebab9050d3',
#   '2bf2455e-6ffc-498c-8c34-b8691053ff69',
#   'd8e67b89-1d17-4ba6-85e0-fdb51641f65b',
#   'f734f5ca-061e-4f9d-9cec-05b80088bbef',
#   '38ba67d9-2fad-4bdc-b079-48a923e93631',
#   '003ba0bb-5e09-4030-9a29-f3705f6e1afb',
#   '0557fde7-2be4-446a-bd0c-46d6fbd352c0',
#   'fc296b91-056b-46f8-8ef2-e911e1f5ede0',
#   '8e463040-08c1-43be-9f3b-809611227a5e',
#   '0e934775-9fd0-42c9-9a8f-850c52155610',
#   'ab72a94f-c216-43f6-887d-d7e7ef748fad',
#   'a7736796-9586-40fb-a8d0-7f68bcd3b5ee',
#   '72804fb6-f47f-4793-a194-0f126f8ef4a8',
#   '828ac83b-f2ca-446a-a3de-40ad2644ebce',
#   'e3a87e68-d99c-4d45-8711-3d20e9bca924',
#   'c2fdf422-d474-404d-a886-a91344d37d5f',
#   '5ebed4c6-f0f5-4ddc-9804-7aad038a5c90',
#   'dc5b9a48-dc8a-40fa-8326-4265dc6c9b3f',
#   '9b4fa51c-0c9d-4b8d-850f-5ef19282a299',
#   '578cc36c-db8c-4bd4-a4e4-97a418dbf6a4',
#   '4ec96d7a-fc40-4104-bdb7-bf96bb06f22f',
#   '562afa30-5689-4ecd-a335-d3f5d10012e5',
#   '56d0a542-f4f2-4389-8794-c020125dec2d',
#   'a737e85e-cc22-43d2-9e02-3dbe2c0b9e20',
#   '5a0144fe-e558-4501-a2f9-7051cebaf445',
#   '5a2e4929-727c-4a15-b652-724255525edf',
#   '386e5aab-1bb5-40df-bd0c-47793b7c5b70',
#   'f3c16e06-ecd1-41b2-a2e9-ffd19e2393b9',
#   'fcc9385f-98ba-4398-abec-fb635e21c63a',
#   '034dad26-9132-4a7f-b28e-7a183f848cd0',
#   'bdfbdf3d-a699-47b3-a668-ad67b4c87e5c',
#   '5717f56b-d14a-43b0-a46b-3c9e040f0df5',
#   '96b54c5b-1b95-439e-b0fe-8bcc67e3aa7a',
#   '7ac23a1f-530c-4e18-bf79-a3dfe0cb9ba3',
#   '867a68d7-2cf0-4384-bea8-7baa6cafd733',
#   'ab314683-1a52-4614-90a5-1d0503b772b7',
#   '72bbe874-79d8-47c8-ada6-649c0484c461',
#   'c667f438-c1de-4341-83e7-238c3b468724',
#   '1160ad72-b4fe-444d-a18f-e2a35c49f693',
#   'd673daf7-7d8c-46ec-a09e-15a1faedd46b',
#   'd598ccc6-ff48-4280-bdb8-b422e9cc1277',
#   'a7c120ff-18c4-4a72-9f60-a18c24e377da',
#   'c7c52951-1f82-4737-af63-973774fc66ca',
#   '12936242-d4de-45fe-a5e0-f2f2d0b3b5ac',
#   '7fef42c2-011f-4320-9968-c3808f855cd4',
#   'b4521a8c-d261-469f-8b48-fe147ed636ea',
#   'b5e04909-921c-4cb1-8834-9955fba0c354',
#   '55bcd97b-dccd-4b22-acb2-00288c2eab75',
#   '733b3ef3-f7f7-45f6-a2c1-56649f7a0853',
#   'e254b15e-ba82-45bd-9ad4-29323fb5a2b8',
#   '827c6361-da3d-4ab6-829d-dd4b15ac275e',
#   '12f5b561-b915-46fb-ae44-4ba4ca509c2c',
#   'f4290306-c8ae-48b6-b42c-2cdf97f0df27',
#   '6b2c5f71-b440-4d29-851d-88dfa6de46ee',
#   '48d75843-8ff2-4be4-9c53-e82807dd791d',
#   '19de8c10-ef4d-41be-8c57-15025f7f9f45',
#   '51f263f1-b54c-4979-9b01-2645df5576e7',
#   '2a4a9a97-0756-4295-9322-78a25f424db4',
#   '4f8d512c-2390-4e3b-8371-c112713cb1ab',
#   '5dc59079-4f75-4d55-95fe-fc5fbb1eed61',
#   '57e10bb1-4182-49e0-b5fe-596d8b40ab31',
#   '63ea5122-f10d-4ae4-b802-8c038cbc5d9b',
#   'f7fb27bb-f90f-4081-a919-783acb1e699c',
#   '1b0bdf56-fdc2-4b21-aa7a-6604b296ee53',
#   '224194a5-40e7-4bc6-ab5c-74719426fc6a',
#   'fbdfafdd-9239-4115-bef7-4fa72e3be1cd',
#   '8f49e928-2cc1-4ee9-a03f-b138e1f2701a',
#   'db0c1b07-b892-4c27-9006-b43f8fb9ca3c',
#   '476584e5-2488-432e-85da-edad54edf7ff',
#   '77f3f190-f0fa-490e-acc6-5cb468147bb3',
#   'ca4ae730-48f2-475a-9859-bc867f87cb21',
#   '69f8a2d1-0821-485b-bd63-7d71280af2db',
#   '84705ab0-bc3a-4cef-9984-9dc09378d2b1',
#   '2de84f23-e923-4da5-9add-673bd1ada864',
#   'f5100fe4-b96b-4c7a-93b4-e93827dc2328',
#   '5cd026c7-581a-41ff-9f69-d7a85f77d14c',
#   '90fa3f84-31ac-45e5-b065-83b0f17a171c',
#   'ec4be6d5-433d-433d-a1c3-1f67af07b257',
#   '5ae31f20-d6d0-4637-8889-1aa45e9019c7',
#   '4292fa84-760c-429d-9a7e-3ef9329f883d',
#   'a99d1020-2161-46d3-9edf-e52fcd547512',
#   'b7281f0d-9ca1-41b3-9bd2-15c5b7092a64',
#   '6755f90b-933d-4313-a672-cf1cb8098cdc',
#   '1a93242f-2f44-4480-9038-89d854f95030',
#   'ce0c320b-cab2-4827-9bd9-5b61e800c284',
#   '6cfcb137-a1ac-48c9-be77-20cd4425bb95',
#   '1a4cfd05-0a6a-4405-89cb-5d860fa29d1e',
#   '76db4560-f662-4e4a-be29-3d6dc7ddc7d4',
#   '778ce034-8c93-42c0-af46-3dc8be286074',
#   '91bb29a0-afa3-4b97-9c7c-c9d3c69a92d0',
#   '6114689e-0fca-4457-bbbb-fd3fe7b27c3e',
#   '6427aa66-f60f-4fa0-81bc-89dc8978415e',
#   '8d757f07-050c-4920-ab77-a30e4242b752',
#   'a4071295-d669-4caf-b2b2-26e879c4416c',
#   'd37d27db-1848-47c7-bdc7-b9a8f17db6ef',
#   '31c25d82-639e-4ff3-b33e-4983702bdf83',
#   '2b86b987-a82b-44f1-8aa3-04dcf307c240',
#   'fc98086c-5db3-45b6-bba1-05dc4321bd41',
#   '5c1aaa7b-8dd5-486f-b5e7-db26cb09d1ff',
#   'f1e697c1-bda4-4757-bc09-2926f1482f97',
#   'e0a55080-3d1f-47fb-b8d4-968d58c53d8d',
#   '566d842a-a2d2-476f-9f70-6800dd522bcf',
#   '344ea95e-0dae-4208-a00e-485f3c8ee576',
#   'cf006ec9-5d4e-46b0-a443-4ffe2d9d0456',
#   'e239b6ca-d967-4a73-88c4-fbe9da547202',
#   '31db3649-df54-48f3-abe4-5b34768a49ba',
#   '7387f969-9d47-4a7f-9c5e-2adc064c231c',
#   'c9293680-bccd-4aa1-b295-1f2536bd2b02',
#   '642f307e-f839-4343-a67d-d01faa11844a',
#   'e00d1b6e-fba4-469b-b78d-a0244876927d',
#   '57d1b516-dd85-4f20-b971-5ed8e86ea7c1',
#   '368c2a32-6378-4f41-ad75-0385c8a67d2d',
#   'df792109-b0a6-4596-958f-067a652fd347',
#   '82140873-7cbf-40d2-a792-fbdd60f899c3',
#   '112cdd69-d746-42c0-ae31-2e5e06877653',
#   'd40b64d6-7aa4-4b53-bcd5-5138961c2e55',
#   'cda5a78f-e6d5-4be5-af03-eb19bfa11282',
#   '481c1eb4-37ea-414d-8343-452ee32a092f',
#   'b6642280-7782-4d07-866c-38bb4d328845',
#   '8b35252d-604e-4e00-bd6e-cbbb3178fb91',
#   'c740d890-f3dd-49b0-ba1b-ea9c8e3155d9',
#   '28f5269b-f19c-4bf0-9bc9-205f3e7bf090',
#   'a39ba795-348e-4aee-9e1c-368cfa5a89ee',
#   'cae9c251-d78b-4723-acb3-de8f5f24bc16',
#   '8ba72e6b-0979-449e-bc2f-f5afa0111a5f',
#   'a65df212-42ae-4298-827d-21d279168e94',
#   '0da7306b-e8e7-401f-af33-a09afea9d388',
#   'd4f72f4d-7f55-40ab-84c1-19255f602582',
#   '720d2445-8e6c-4053-bf1a-183fd70b1520',
#   '89206cc0-99fe-45ab-87de-50f0eb6c1fe3',
#   'b4ded6dc-6d70-41a0-aeb1-3527b43ca043',
#   'ad11c400-f8fc-4798-ad39-12ae40769f27',
#   '3eff42a1-ed68-4532-b5bc-608546fa4be9',
#   'eece0e16-7c4f-4ea3-af37-a1b4e55f2635',
#   '0c16d802-ecd4-48e4-9d44-2214226e7389',
#   '3263bc07-8b15-44bc-9182-e50d91f8691c',
#   '859d92ed-3b55-4653-b391-d6c91a07bb02',
#   '936f8f4c-82ac-4ecf-b0e1-90bb26f46e51',
#   '53f3f3ab-7cbc-46df-985e-f17d71354016',
#   '1b67d9df-0754-4a24-b24f-4af607ba8ad5',
#   'a0c80dd0-e187-415e-aaa0-a556dd99a729',
#   'b89e8b31-331d-45a4-a725-13d37a7610c3',
#   '8880d126-e77c-4c0d-9601-440e28317602',
#   '87798d1b-c1a6-4ae3-bd3d-b8ec399ee623',
#   '2ec60f2e-a484-4685-9d09-a9491aa327cd',
#   '99b52bf4-b706-4795-b42c-d0cc04c1c556',
#   '4cb7c3b0-10fd-4e01-a941-871f93668f3d',
#   '58669cc0-7336-42bc-940e-8a4c7948c948',
#   '712ba5c9-b82b-4e57-99f7-a0e234af9f58',
#   '0810256b-e411-4152-b591-6c2bd6b15ccc',
#   '60039891-a512-4ed5-9229-5182d85d0197',
#   'c6f47973-80ef-4a4b-b71f-0b97d3ad200e',
#   'd5d45f87-359d-460b-a82b-18a75f2f339d',
#   '58d62ff0-fc9b-4486-8025-6253920c98b6',
#   'f472693b-3575-4e20-a140-2a1946779ac0',
#   '6cc624a3-d789-469e-b72e-32f34b9cc124',
#   '6706e6e6-1f51-4e01-9f66-7cdf27819977',
#   '4dcacb57-50b6-45d2-a365-0abc2cbc26a4',
#   'efdd202a-c9c9-4857-92a3-90688ca3ce5f',
#   '386a5974-881c-4ee8-b390-3a39f70c2cd4',
#   '27dbada3-7f0f-422c-8f32-0ae131f9a4b0',
#   '90fcd666-f381-439d-8b0e-fb37e294796c',
#   '975c922e-a263-4e43-ba0d-6ae58b62c7e9',
#   '875dabdf-cd80-4771-84f8-9eec7cd6298d',
#   'a0d06737-4255-4c21-9e8e-ae787958647d',
#   '46b4acd4-57b7-45ad-81bc-ccd23c8b0365',
#   '430579bf-aebc-41a7-9a40-8cf812355d78',
#   '867883cc-494c-4cf6-bdc8-224c8f4a70fd',
#   'dc4ce6d0-4d68-4449-9058-120113306e3a',
#   'e5b329d5-ef79-4b5d-a5c7-c1fc52f10a9b',
#   'e6e34ef3-8a71-4326-938b-ee8091dba7ee',
#   '7a00f4af-2a27-40a5-affe-65dec6a0888a',
#   'ef73fe27-6904-4b23-afcf-dad0b5027f5f',
#   '7a3fd5e5-32e9-4b3a-a1e9-f3bf38f9191b',
#   'c324e62a-f2cf-4b85-b7bc-f926ce4a96b5',
#   'c9e805cc-3ece-40b2-ab0d-952ce687256d',
#   '49691b96-46bd-44f5-9062-a6fc35dfea07',
#   '612faa79-e362-470a-8774-e26092fc0b59',
#   'ab801950-e1ba-4330-bca4-0d9e94d7fd01',
#   'ba459ea1-d659-4ac7-8f79-96965cec18ca',
#   'ba7c6c4e-8631-4caa-88d3-8e51f6f59af4',
#   '8a264501-d270-4261-8aa1-547033e02cb2',
#   '608cb4cd-5805-4776-ba95-e96a72b450a8',
#   '03c20a00-deb1-4215-985b-a95156a54d96',
#   'ace63d61-45b0-4576-ab71-ecbf94e36a22',
#   'bc968017-9116-4169-9e99-11747c506066',
#   'c867daa0-4058-4bb3-bcfa-471370058536',
#   '19f60a28-fc84-45a5-a083-c34df669d292',
#   '50cf936c-39f1-4ab7-8bcd-ff6c5d02e9f6',
#   'bece80ec-c6f6-4909-bfa5-f66203dd87de',
#   '66e801b7-46ee-42bf-b304-13bd347781d0',
#   '94053b00-4e8c-4aaf-ad29-e5bb103fe9ac',
#   '8eee4adc-e3ed-4cb0-95c0-114096c66bd7',
#   'b2fe22c8-731a-41e9-8b12-b60dd9222064',
#   '94bf9b48-93b0-4cb7-bb2b-d1a1bf9584e8',
#   '73187a80-b996-4a6e-aa31-2a65c94145a9',
#   'f2d3cd3f-ea25-464f-8711-274bcf981331',
#   '99681b8a-87c4-44e4-85c3-8efa184b3267',
#   '01ba7968-0f21-4749-8c0a-6479344a47aa',
#   '7015d776-02fc-4627-9cd3-02f55c0d99da',
#   '72b4e049-d151-49b2-80e2-fb11580e7c88',
#   '3e6a6297-03fe-41df-9fab-573c87f4a9a1',
#   '2dea41a3-6806-445d-b528-e0bb858d7faa',
#   '7774f4cf-9666-4b9f-b6c0-2c62c5d0eb5b',
#   '09b0a80c-dcca-4fa5-8fd2-b009ee6ccfd0',
#   '1a92e954-45e5-40cf-90fb-5b44e04aac61',
#   'a1341649-b594-41e5-8a5b-efb4e2ff6f81',
#   '1557d90f-32bf-4cb9-b877-f4eb0b677ce3',
#   '523ac485-57b9-4c61-adff-b996d6f86b3f',
#   'cfa49f05-2295-41ac-b70d-348389778055',
#   'b5ceb2f8-2da9-42ca-9f6a-d9525437d9d7',
#   'fd48d335-7480-47c5-b61c-9c52e6cdb70c',
#   '6a611bd7-9e90-4148-9602-451320fbbdaf',
#   '999ce9e0-0dc5-42c5-a38e-d54ad376881f',
#   'f70372f7-f2dd-4abd-90eb-8b243a9c3048',
#   'e3ffd105-fd4e-4a0f-b932-780670fe389a',
#   '73725732-2425-464d-8013-6fcc53528d4a',
#   'bdb88b29-46b4-4159-9db5-63deaa30dbcc',
#   '2b4f6584-04c7-4e78-b95f-9c383429a687',
#   '8c863103-1b30-4443-9665-7dd58e5001c1',
#   '022e9ca5-2952-47f5-aa1f-3845530e03eb',
#   'bad67f87-a317-4863-a38e-b1da16cb9d5a',
#   '5c20a33d-90a8-4a32-ae43-a599fc3a72c0',
#   'be31bf61-3fb7-4d42-b126-b82f077d2735',
#   '43092f6d-b5ac-48ec-b0e4-8eb6e0df99dd',
#   '06587f84-acc5-418c-95e2-f8644ce5fab9',
#   'cbe86478-97c2-4bfb-8d01-518500886a32',
#   'f4a22e61-785c-4013-af2b-ec8ad3013d8d',
#   '29a6ba88-6a8e-43b6-93d6-1932de685c16',
#   '6ef8c8f5-a243-486c-a30a-bb173b60f36a',
#   '88dd7d91-6b7b-4830-b7c6-af796ddb98eb',
#   'e9c6b3bd-74c7-431b-9599-95ac1ac2fb6e',
#   '4bb0b20f-72f8-4cd5-baf0-0f6dab3f40d5',
#   'bb475531-2bb5-4688-b372-b2bb60bd7ca1',
#   '45321bce-3ae1-4bcc-aea9-1bf6ea5bf0b7',
#   '3d7b570f-c7b2-460a-8268-12f55dda0b59',
#   '6c7f4cd7-c52f-48bb-bd8c-98bbfec16ecd',
#   '6f929a4a-9743-4500-bc07-9220cda1c08d',
#   '9a254b0e-b9f4-4b52-86ac-ca2d946d7af4',
#   '817f5071-7f36-4f3c-bd0b-5ee6c9fd42e0',
#   '7eddefe8-0d56-495a-a7ec-d20d6ce37728',
#   '1ea933a0-bb7d-46a5-871f-a5046e69cf0e',
#   '43217fc7-dd24-4972-8a6b-b40558352acb',
#   'd05d6e9d-84d9-4a61-9c10-2aa81a725b14',
#   '0e14ba38-b867-4a59-a596-3e0a1c097025',
#   '8e2d9aed-c3b4-4dfc-8bbc-f964cf21e16e',
#   'cecf6c01-b0b0-4c25-9c75-c2c1d42db6a7',
#   '45e97ffd-f4b7-4c3d-9327-05c2844c2a52',
#   '8aeef6ea-6429-43a1-ba39-1ea761df1a12',
#   '5138ed8e-d677-469f-b41b-47397b8ddecf',
#   '53c42c0c-e4d8-4dc7-ba79-00de8edf8b75',
#   'e74f4816-7355-45b8-bde7-8e494974a70f',
#   'e8365b5b-de78-4b1d-9ea0-f4d7cb9285ed',
#   'c27b372b-bbee-41d7-8989-4ad5ce87112c',
#   '1a42f86c-452c-466a-8930-5443ec49186d',
#   'b0ee698a-20e7-4d69-8be3-db11e946cc99',
#   '5414f476-02ac-43f2-8222-b5c9ac6114db',
#   '521b55d1-f767-4842-a7fd-ccab92c49c8c',
#   '1823ab3d-60e0-4faa-aa8a-270db217d3e0',
#   '31acad66-36b9-4f9e-936c-54553808983c',
#   'd23cb8e6-8086-4685-98aa-86a9f53fd6a2',
#   '3669814f-f50c-4e85-8620-dfdae00becb2',
#   'b3dc32db-d298-4a60-a954-a26cb3bd9eea',
#   'f540e0ea-97a2-4ca0-98d8-752dcb95a8e2',
#   'bbdeb177-5818-465d-92d8-f3eff11286ac',
#   '53e0b31a-e125-42d7-915c-297385484ec7',
#   '6c826345-9e52-4fbf-a517-6a56b1331095',
#   '2074e60e-dfd3-45b5-a320-72bceef76313',
#   '46633106-e10e-4a00-b3e0-0b11207b2e77',
#   '4e57d011-c803-429a-9506-9e8f2d024fdb',
#   '365661ee-478f-4387-9fae-bf0480a80610',
#   'ad9ead88-ff63-4018-a6f0-9912dae07bf7',
#   'd49c39fc-99a4-4dbb-be7e-1fce4d4577c9',
#   '4ba95df8-6202-48e1-a29f-23f2b07c7b2f',
#   'ac5f73a7-755d-4869-87ce-cfea33bc158d',
#   '52b2757f-64f4-4e1f-9606-3e16b3465012',
#   '7475caaa-ca82-4b78-966c-e85947ce23cc',
#   'aa3f512d-3c44-4f8c-930d-df0456a0a079',
#   '1e31a3b9-a67a-4980-beb4-f9cd66431cd0',
#   '81718130-d7de-424a-ab17-fd5a28c2b5fb',
#   '9697f2ab-e1a0-493b-b92a-1d359b641b50',
#   '61e905fc-b55d-441b-a18d-73a3bf8cd769',
#   '56cbc28e-a018-4e40-87b8-89b149a24308',
#   'e8af9961-00bb-44d4-bb66-5edc971076d7',
#   '887dd2b5-3fb5-47cd-b9e5-67e4064e7254',
#   '28920a7c-579b-4e0d-bcb6-f83db6369f59',
#   'd3a2fd2f-085f-4fdf-8359-f98391a2f11c',
#   '94e0ab78-2579-4ee5-8c25-28072af82dca',
#   '603df13c-fd75-4751-9683-869dcbbceaa0',
#   'b9d990e0-7b0a-40c9-9676-a401486b1169',
#   '72596880-20a7-44b5-a16f-1bb623e474f3',
#   '9c8d59de-fd31-4052-a842-547cade15218',
#   '78d694d3-5e26-489a-8175-228abdf2b35a',
#   '848b66ae-3898-4e91-91a4-9055f7677926',
#   '51179784-c63b-4eea-bb65-e7957493eb5d',
#   'cd5bab0b-4562-4b92-b774-4ce2c0e2dca8',
#   '94ffc3d2-53b0-4822-8415-4c2fd83329a9',
#   '54387e57-8560-4951-b142-7c46db1a5406',
#   '8134a1c4-c3e2-4b27-b4ed-8f3a4d6a6f8a',
#   '5bf3f631-6287-466c-8f4e-a384d63df09e',
#   'f2f88664-ebd2-4a00-bfd8-2e58ce45de09',
#   '54f85b5f-c185-48c2-b968-a03b9184a3f4',
#   '1274d37a-028c-494a-99fd-7a1f6cb0c9f4',
#   '27dbfecd-0182-4813-9da8-1e58c9b44fae',
#   '5c55cbb0-5b83-4450-a454-493eeaa0979a',
#   'f75bc08f-e20e-4f4c-accb-eb1208a9df23',
#   '4f3d154d-0fbc-4a95-8ed1-0207d0f0bd85',
#   '3bcc5aab-ec8c-4017-845c-9516e825adf2',
#   '7e7d82d9-3f0b-4e77-90c6-71ab1014eb96',
#   '199cee6e-d633-4743-8bb4-92976e59d9d9',
#   '8c199444-9384-475b-b54c-8b48c5be9802',
#   '6d3a3f9e-018d-48fb-85f6-59c8c016ca00',
#   'e2043678-4951-4670-a843-f04ce7c9244b',
#   '1ad3fc04-9850-4fdf-ba9e-60773e2696bc',
#   '3db676dc-8f88-4d5c-b0b4-327fb82de5db',
#   'ce94e6f5-46dc-4b46-a3b3-9a3bf2a09003',
#   '0fc2f5ab-7046-4687-adef-5c56469e2099',
#   '52162a0b-ad8f-44a9-bb3e-c2ec760bb288',
#   'c9a1a7e2-1a43-4831-80c0-e46afbd6d877',
#   '44c139d4-b16c-4192-9e6d-cf9b99a22129',
#   '0fc63f3a-a4fd-4f1e-9b73-4abf6649d2c2',
#   '3e5844e2-4f1b-4161-b3e7-64ec8d4ee5a5',
#   '474993a3-ab7a-4e61-8d1f-d895819c6ffe',
#   'd5e61554-1a53-4a74-9c56-d6be9eadce40',
#   '2493bfb1-048c-40c2-9eb3-6fc536083638',
#   '95f0488f-43a6-40ef-91da-d1a3849d038e',
#   '4300000f-8977-491b-9d34-89d8d1ab0532',
#   'bbb1d32c-9aed-42dd-bdc6-b9784c897388',
#   'c5939a5f-b4d5-4e54-86a6-c7c0972187f7',
#   '1d0fc42c-1ea4-4544-a1bd-158776af9ce1',
#   '23731d92-964d-45b8-a7f5-9b2aff406188',
#   '938ac32f-3cda-4cc7-8b79-c725522f6d31',
#   '5ab5f9a1-4227-463a-90df-5e68524ce9e8',
#   'e13c8c98-6dd9-426d-93b2-eb8f1ab7526a',
#   'c102627d-1053-440e-94c5-ef0d90c25784',
#   '268eda10-32a7-4e67-b58d-88b86b9f7f83',
#   '65d483ec-fca3-4ab1-abbd-3774f20f1eaf',
#   'af246fb7-6821-48c2-88e7-67d64c77c87e',
#   'e6c5985a-3eb8-49b8-95d1-1a7131d36161',
#   '3958f49f-6d1d-480e-aa53-ce5387ace6a1',
#   '00ac0392-16d0-4f60-bb19-e96fd6274f02',
#   '22dba365-dd95-46bf-ac80-d1a7d3eca1d0',
#   '9f97f11d-5b65-4806-83dd-8ad13f33e0b8',
#   '2be0cd90-e3d3-499a-b69b-eff0984096fd',
#   'b4f0ed0f-f978-43ca-b24f-43acea676c00',
#   '21a26aa6-bcf7-4f5b-88d4-d55d54683412',
#   '2269bc6e-9de4-455f-bc8f-6beef498f06c',
#   'd651c4c8-dc3b-4381-adbf-f68b3289e6e0',
#   '227632ba-fe2d-40ac-a1c5-e47ff22761e5',
#   '647f17cf-933f-4f57-a9d0-f8080acdcb2d',
#   'c051d90c-5c3e-440e-afa9-8f704cc6855f',
#   'c982c1fa-8277-4c2b-9c58-681b1d64845a',
#   'a05f5e4e-6bf5-43be-bacd-482320e4ea7d',
#   '2e25fb6a-9471-42f3-927f-405e2a8346f6',
#   'e59661d7-b58e-4316-ab49-14f764f0c6f4',
#   'edab122b-0a5f-4554-b97d-771a72a06c28',
#   '3552b90e-af02-4d1c-ad13-dcb8ddc98f53',
#   '30db3fdf-6a07-4b31-8e06-67d295d57197',
#   '1c5d0e97-7e94-4fb7-a62b-5a6b0fc485a6',
#   '1e2fca85-ccf3-4173-aa7d-c82cc0d568bd',
#   '30674d1c-7cbc-4d12-a3ac-f93946260d28',
#   'fc73bfbc-c43d-4c8a-95c8-edbc4e8e2420',
#   '3442e8dc-910e-4759-b328-d95cc3fe570a',
#   '753174db-a3b0-47f7-b186-996e56c11ebd',
#   'f8ed2337-f048-43c5-8e5a-3cd4cead1e28',
#   '1aef817f-6d99-4c6e-8747-4fea33d6763f',
#   '4b2ccea5-8038-4017-be05-07677c41c01f',
#   '1474a9e9-4784-4ae2-811a-35c2df21cda4',
#   '05c6ed10-124f-42e9-b178-212bd46caf5a',
#   '9ba91395-76f1-4a04-9548-68ea644e9c3a',
#   '693e979d-c51c-4d88-bce0-12312ee0f90c',
#   '2f2bc7db-40d7-46cb-8b2f-4fdbe103a5a9',
#   '4bfab2d0-b74a-4c70-958f-915d23d361ac',
#   '654a8722-3407-45b5-b05d-092ed8f81b64',
#   '3517e1d6-e730-4232-87a8-3ca27896445b',
#   '14605b27-ba60-4532-8f12-765f719eaef2',
#   '92186a18-3a9b-43b9-9c0a-ec66b48fa0ee',
#   '4342d917-d771-4186-a387-694f19b2af9e',
#   '464ea344-d97b-4ad3-a7ec-3b789046f768',
#   '8ba6c041-016a-41f9-a306-23af393f5a14',
#   '69c517f6-5435-4373-a085-e26e34b14d2d',
#   '9d184c9f-2349-4510-8b34-e282957dafbc',
#   '3650b205-96d8-43d1-8601-78177bb243ec',
#   '34b9e337-c0d8-4da1-9e87-d4d3af058606',
#   'f818ab7d-4566-4f2e-9b41-5b51f06958cf',
#   '2823054a-4304-4ccf-b412-90b30ebe2626',
#   '47fe93da-bc69-4753-ab22-7aeb646e2b5a',
#   '381ab450-0b86-4ba1-a432-57fb4c10afa4',
#   '43f851a0-875c-4144-8098-99b134ef667a',
#   'e4daf7bc-4474-474a-a8c6-35af6a6339ce',
#   'e8704c0f-eb56-47f0-8525-4ac8c56dae0b',
#   'c422e630-a6bf-45bd-951f-00f2f0f4d51c',
#   '282dc990-d5d0-416c-88af-8532906aa72c',
#   'd7cc4d9d-4085-4edc-8b36-0c07cfca7259',
#   'e0ec4c3d-ae78-4c3f-b051-37fbc1397526',
#   '1fddc135-10e8-4a1b-8cb0-b77236cb578a',
#   '6ec83ecf-cb33-4310-8335-8f345476cd9e',
#   'be603213-a9ac-4237-b926-7d8c3789ee8f',
#   'dd5eb70e-e12e-4eb3-afe5-65878e24266b',
#   'b8c0a781-04f4-4e54-9272-414c7544e3fb',
#   '8599ae90-9c19-4945-98f7-59e18cfd1ef2',
#   '2f972b0a-74f4-484b-bb47-b953e3b04b1e',
#   '392d941a-134b-4aef-b79c-b08d81f569ea',
#   '1b88fa98-eb0b-4884-9ed5-c4d6f1b7572a',
#   '53907275-64cb-48f4-8b94-43317de2a89e',
#   '6c9f3523-a4f0-46fb-a02f-c70363f7592f',
#   '23015ae5-eb9f-42b7-a0d1-1f07373da888',
#   '94b03179-f150-4659-8e9b-2fd4ed3519f9',
#   'b1bd48da-c1f3-4e88-83b3-fd23ac45c3fe',
#   '13b5611b-e08f-4f98-9845-2ccaa9f5b41b',
#   '9671cf40-337b-4c98-b58c-dc6ae6cfba8f',
#   '7bdbcaa1-cded-45e0-a8b7-fca30a7ac68e',
#   '0e4b2a8f-2ca2-4032-a3de-7fa794f6a185',
#   '99c1409b-9b18-482e-a7d9-7aac08e33676',
#   '2b0cb012-f765-4d69-bce2-1e30f6c5641a',
#   'd4e44209-4d10-40f1-b857-e4dde032f764',
#   '253b82a6-c5f0-4c48-a2d2-d6864959b24e',
#   'aacb9145-a4cf-451b-a077-313073ad9b8a',
#   'b6402a52-0343-487a-83af-0f8c96fd66d2',
#   'faea25bc-ca07-4cb7-bed3-9498181e37cd',
#   '37ebe8f2-9a7c-4b3b-998a-909c906b8184',
#   'be4b13e5-9958-4095-8b7c-78c692b9043a',
#   'cc7ef4bd-5b04-4a2b-8232-4381541198ea',
#   'd9acadd0-23f9-4cb7-b73a-4b705b0862ca',
#   '7f90a085-d612-43ff-9c69-21ada4e76a1f',
#   '33ee362a-d275-41ed-8818-73141c88656d',
#   '5327ff9e-8884-4400-9c6c-816c2c17090b',
#   'b8ed1e66-9da5-4625-a82f-370696aeff55',
#   '95350c0a-9af0-4574-81fe-278b6ad3eb85',
#   '4dbc18c3-c662-45e6-a3f5-365a1e90e587',
#   '30d706fd-18ea-4628-a591-31a96b026010',
#   'd07f51c5-b6f0-47ce-be33-d337a0769a9b',
#   '29034b7b-2514-4277-b7cd-2bfcfccaec36',
#   '2589f500-d2e8-4718-9a25-f7f6f9fde35a',
#   'f86292ad-9dd0-48b8-991b-6c7310bdcd7c',
#   '6cf5e26e-8a8f-4dcb-b433-26d223a2e72f',
#   'bbfd1329-9a28-4432-9162-1d3d020a5726',
#   'ef30748e-bfac-480f-91e9-a088563d5a59',
#   '2f644b0b-62bc-4b41-a094-b14779b4d707',
#   'fe609fa8-0db7-45a7-91dc-50886ad3f35a',
#   'c0900e7d-f10c-4642-a589-7f5d70c15f7a',
#   'a4c68b7c-b20e-4215-bd6a-bf80090e5950',
#   'e240cb72-aeae-467f-9bca-52f5c921d1fb',
#   '756386a5-1f63-4e1f-8d1c-84204fefdf6f',
#   '58096893-c3bd-4fd9-a44e-c4e309cd9e5f',
#   '768f8447-cc03-4dd6-ace8-e3a61f2258da',
#   '66e64be2-fea3-4481-830b-ed4825030031',
#   'f5607152-8419-4b28-8961-e5d0c0db6862',
#   '5bd297ea-8bb0-43e7-aa5e-ac33e6650190',
#   'fb795424-9f8d-46e6-b165-bd7761f83e5d',
#   'f934fb94-ae92-4ef1-8905-be0c20d1cb9e',
#   'e8ce58be-a342-4f9a-bcaa-bdca4b9beb96',
#   '23d7e017-4fff-4f46-8720-5f394dda94b8',
#   '8be5d31f-33ff-45dc-b280-ecd12bff85dc',
#   '56ac24a0-b29b-4722-a9e1-297263f61db1',
#   'cda28c89-9869-4625-8980-4d238f90fe4e',
#   '0db5bc45-57d2-4601-b766-a5e17a677dbf',
#   'c12e0404-7906-46b1-9d33-2827e2237828',
#   '53f36143-695b-48f8-9f9e-2c460bb9bf4f',
#   '774bbae8-5de9-4f41-be4f-e61dfb29d910',
#   '7cf77c82-553b-49f2-bf02-7e5d4a8faa61',
#   '07b94686-1279-4722-8902-ad5d9fe6c952',
#   '1a11a0be-28e9-469b-9c07-6988a249c8e2',
#   '8bbd48f3-99c3-46dd-8d21-700c6bfd58f9',
#   '4bd363cb-bab0-4de2-a918-acce01249ef2',
#   'fe2b2f9b-1e4a-4651-b1c7-2068edc51830',
#   '7aa5590f-b2cf-4cd5-82f0-087afec54268',
#   '6ebf3b52-94c6-4e2b-acb1-f0087ff8cc95',
#   '4a8bebe3-0c0a-4a4e-b9f2-e18f8d9782b2',
#   '49a1b36c-3ad0-4252-84e7-a29d078ffa7c',
#   'df502813-3ca4-4f44-bfae-cf1eaab038f2',
#   '8e4f4a1f-8194-483f-9f6c-6da69cb5c994',
#   '4f08a763-08aa-4246-b0ad-f9e45110e75c',
#   '66326fb6-86e1-4a33-ab02-9231a211eae1',
#   '8a0a150c-3f41-429b-81a2-9d0ee7b80999',
#   '1c45ef36-7fce-4327-b287-2308a70bd843',
#   'b159d026-5d6f-444c-ad1f-16889ceddb14',
#   'f0c7d398-7520-4beb-bbb6-ea6e25375af2',
#   'f5bf98d1-e25c-4697-b171-1c028523ac08',
#   '7e0dd900-5ab3-4897-8698-8db63ddf00e3',
#   '1deca71b-b514-49a9-a4d5-073f4438269d',
#   '30f6a33a-3186-458c-88e8-796aa10b70d6',
#   'bda5c692-0ae1-460b-8747-9b56f5c0516e',
#   'b01f8f11-5d74-4f0a-8b05-deabadf594b5',
#   '4ab1d8bf-c020-4d95-af2c-00a04ebcef55',
#   '3a46c5a7-7467-46e3-84a1-888b60d09b23',
#   'd27c0e5d-9932-4862-9378-50b24381c0ff',
#   'd33f32ee-c62c-4549-8471-a89793b890a3',
#   'b9ad258e-bf30-4175-85d3-9c748b6508b9',
#   'bd3b849f-01ed-4f7a-9315-17c91efdf166',
#   '6ce683c2-609d-48a4-8c54-082b4869e1b0',
#   'b0603110-1bdc-448b-a421-a657cb4fcdcc',
#   '83690546-f6dd-4fdc-a234-bf94163b5532',
#   '99968f3c-b4ae-4d5e-a8cb-778b2516c06f',
#   'b1cf5eab-ca3f-477b-b08d-c3f3186febbb',
#   '3772679a-841f-4eab-b26a-d324522e0eb4',
#   '39b0e037-cceb-420d-a6fd-7ac6b8b7518e',
#   '7e1703d5-4c65-4c98-8b6b-1fb4cb0dce08',
#   '770914f6-6986-4cc8-9745-f3410d8352c7',
#   '67b97730-39a3-4643-b26b-abf695cfdcce',
#   'c630127e-66fc-41e5-8bd2-1b2d35031c7c',
#   '066d4ef3-4454-4715-986f-6b0c6406c4d7',
#   'f0040dac-0992-4ff8-8090-58640d72a0ae',
#   'eb383c25-8990-42d1-8a1d-6e860f3f76fa',
#   '3c01d231-a3d1-4c70-af07-4791bfd55ba8',
#   '74e46947-6126-4156-bb6a-82976610febd',
#   'acfd87e9-f53b-46a4-a9e3-0f85f2fb7301',
#   '78643a2e-ebb0-4af9-b98b-8584d8c161ba',
#   'f9718a39-e32b-44da-a886-07a6510fa06c',
#   'a3c276c3-de77-41f7-92bf-399b35b056f7',
#   '28b56d69-bada-4b54-84e4-83e99b703837',
#   '3073f1ac-4e15-4916-85ae-3d2f46ed51ad',
#   '1bdf7909-c6c3-4e2b-be75-1f2fef1952b5',
#   '1010f007-d1fc-48b0-9c52-39bd4525d211',
#   '63106c54-260a-47ec-b40c-4dee0b5497b3',
#   '548a2050-7ba2-4561-ba22-03a03785d5e7',
#   '8e84f01d-3d91-4ccc-b4fd-c1f83a50a8fb',
#   'e9d4572d-beab-4ac6-a9e7-65505c8117c5',
#   '3589a67e-7aa1-45a8-921c-4779520d838a',
#   '23745af8-a482-4ced-93fd-26416f030abf',
#   '60354cb7-04f5-439b-8d56-23340f06fee1',
#   'c071312b-5076-4bcb-b772-65e5663941d0',
#   '26cfb33b-6843-4f3a-92c5-45063f7244ef',
#   '951a7d1d-3724-4dbd-be25-d11d533ea34d',
#   'f011f706-3463-4359-bd9a-76abf07dd7ea',
#   '74203c52-013b-4e8d-8f1a-7a399ea7feb2',
#   '44d9b8d1-2175-4b31-b6ba-29f3f5ea2a8c',
#   '652751d8-69a7-408f-801b-66c4d7d136b2',
#   '3329b745-2d9c-48d9-8e17-591449023f03',
#   '7bc5037d-8748-488b-b5f1-48c53fa64f58',
#   '95aa1827-33da-49a1-9577-34f41f3b7a39',
#   '384e8816-6f66-4d45-958e-495e5c6da3c1',
#   'a08e4dbc-4cd4-4185-91c2-b84e06134b75',
#   '4678eca9-12fc-4557-a768-906229c99d3a',
#   '72e15c8b-1b2f-4d69-8e3e-2e79ec824a10',
#   'e6fa10a5-89f3-4ce9-a610-d4d6eded3a83',
#   '4de08fd0-1b53-4e08-803b-64ff4f161300',
#   '680d24dc-b678-46b8-a5db-f2afc939eb28',
#   'dfb4dd43-f60a-4cbc-bdf4-17a5688d559b',
#   'ef24cdf5-75cb-4e09-a6b8-384fe1ca36ec',
#   'c883f239-6438-464f-a04a-907878c1be1f',
#   '3c24c81e-a72c-4bf6-8479-3be0581b6779',
#   '271b417d-f9f4-44f5-aa3e-10c5eebfe146',
#   '509a5fc4-70bb-4b3e-8060-7e2720079b38',
#   '3974c62a-3ff1-47aa-b03f-13e3f7605648',
#   '635cb9ff-d676-421c-944f-2d0476abf1b0',
#   'c90dcafc-8e5f-459d-a0a1-2466ac8e01d0',
#   '3fc7ed17-f453-4e1e-ba73-0107bf0ed4a5',
#   'f9f4be14-e261-4a55-976e-691bf6045644',
#   'd3c137ab-e5ba-424a-8f24-440f3c7011f2',
#   '2bd0cd50-3557-4551-8b3b-25955cd81185',
#   'e4d93c36-0a59-4d68-b463-6f49fd5cee3d',
#   'e8387559-41fb-4cea-84a8-5bc74929bb9c',
#   '9da61d53-993d-495e-a227-a5887c8e453e',
#   '1fe372b8-cc82-41dd-bc69-4787e3196725',
#   '2196cbf8-84fa-49e0-81f4-8242fbaf3542',
#   '50fc5a71-7a36-4636-93ea-f584574c3b0d',
#   '3f71e310-ef20-4e91-872c-c4ac99a13972',
#   'd34b0981-6050-4734-853b-a527904264fa',
#   'b4540fdf-4d94-4562-91ff-e6c5e58a6b56',
#   'dc13658d-6f62-4ea1-a092-37c9d030e7ca',
#   '345d2b90-9350-45fe-831d-bbfcc3910de5',
#   'a6a9d653-f900-41fd-b861-0419fe2a161b',
#   'b8a2170c-7c13-42ad-ae47-a9fc1d5db7c6',
#   'bc93af89-6ee7-4925-90f1-461606cede56',
#   '93ecf6eb-97f0-4251-a699-50ebff58954f',
#   'ef9c1fc3-9673-4741-b784-27f12c957ec0',
#   'bde9bef6-d353-401f-98f4-17aa66d2968e',
#   '9b17bbd8-8856-4df4-b87f-32d11763c0fb',
#   '49781512-c4d0-4784-814f-ea363c628dc7',
#   '1a337a3d-4ae4-42b8-9473-96bf3752af1c',
#   'a43cf1e4-99f5-4e08-8dbc-c4a0f5507ab2',
#   '69a26689-8958-4de2-b132-553cff3f85ea',
#   '3eb77fd6-cbe3-4193-bd6d-e79591699672',
#   'db0336e7-87ed-4fd1-a479-826ab868454d',
#   'b65afe84-648b-4c8d-85f2-059ee99fa652',
#   '5b13f85b-fdc6-4ebe-a50c-94ed75a6efd5',
#   'de5ba131-bf6e-4701-84c2-98619ee3540b',
#   '4990d5fb-ec3e-47dd-840f-ac4bce83fd78',
#   'e887056a-1ba1-4e72-9fa5-ac57c6f1b632',
#   '4b503a79-82a2-4902-887e-d527b1440444',
#   '8603e7fb-c5c4-4f06-81d3-7f38a5be8511',
#   'a6c4b9c9-979b-4cc9-9117-82348bcc3a54',
#   'b416135c-5905-4de2-b20a-0009e670e189',
#   '4563075f-c29b-40ac-988f-c45474938e59',
#   'b8f447f7-f8f3-41cc-a83f-1ff87e85d243',
#   'c1869d38-9ee9-481e-b46c-07a5d9bd11b6',
#   '42033951-95fd-4191-b2e3-12b6081f9a8a',
#   '1876d5fa-1d65-47a0-9612-b4bf61862f2f',
#   '30ac7269-a415-4e62-a6c8-897f9686771d',
#   '7c9f45b9-4339-4409-9f2f-52894053b944',
#   'd7c3c411-3e78-419c-bfd4-db58799b5ab7',
#   '6cde5718-7143-4475-91bf-28940ee7065e',
#   '7dca62ce-af60-4342-9186-12785ec67100',
#   '6a8516bb-5e06-46ac-aa6c-e42371748f70',
#   '4e3bc6e5-5d03-462d-a68c-3850ba1ae1da',
#   'e4e2d1f7-6c73-42c6-8524-bd1e121a1c9b',
#   '5db7942b-7281-4828-b951-4bfe31d1acde',
#   '45d703f2-f756-4c9e-99ca-ca969b2a4476',
#   '034ce7fc-d6ae-4ee4-9673-11c8f43fabc1',
#   'e09fa500-8cbf-4dd4-967e-c42a93c2d072',
#   '50825dcd-303d-4865-9ff7-fbd8a6bb6509',
#   '97226326-3987-497e-80bd-f943393f2fbc',
#   'ae1b42a7-85ba-453d-9a40-410f6a2e12d2',
#   'fdb19bed-7638-43ad-82ad-2bba26706726',
#   '67b0bad1-ad6e-4f18-9b9c-58af04e48946',
#   'a272c221-7d95-4113-b61d-3420533c2ff3',
#   'b3b4bf3a-590e-4571-ba4e-f32a48e4a517',
#   '07f17de9-8c8a-4c59-bcd3-4b63ae9f29fc',
#   'af688e22-f76a-4b7d-bd74-6acdd753c552',
#   '56959573-675d-4998-9588-6b4b2299ebd9',
#   'b447714e-a689-4e23-b505-34181ee51f1c',
#   '20d3eacc-8b67-4f88-938f-2cf77cd1fc2f',
#   'ad570502-4cb0-4cfd-b237-f72d8c28dc78',
#   'dd47011c-265a-4a1c-a9bd-5076649922d8',
#   'd656f857-b1e7-4590-84de-fad8745b81e3',
#   'b2f05572-0a5f-4eff-9534-41a117a1277c',
#   'e12cf287-e351-4a1e-aee4-3c1654514d49',
#   '845a91d6-fa25-48ce-908a-22b15325d692',
#   '643c647b-e38b-45cd-a915-59aa87cbe21a',
#   'a7552094-7d37-4c7a-adda-06f350ec8de4',
#   '98509d27-1aac-437b-a3d5-65c2e8e4c88f',
#   '6f5005a7-6965-411c-9936-11622498acfc',
#   '5986c1be-bd43-4cf5-87ae-354293727982',
#   'af1a2c3d-418b-4cce-bbef-98d007347e9b',
#   '87c46f50-17a5-48af-9d22-25ff3cf432b4',
#   'cda51fb6-b066-4160-95be-25c4c26f6ccb',
#   '8baa423a-ae2b-441d-a0b5-21d360541906',
#   '49539e23-9010-4a50-8ad5-88ee848a7028',
#   'b765a208-2696-495e-a089-ea344eeb222a',
#   '055c05a9-85ae-4c55-91e2-2ea530166588',
#   'a7f9a4ae-9581-42cb-8c1e-ed140a1ff2be',
#   '3ccf02a0-80f1-4d03-994d-bf779a724839',
#   '70838ec9-0745-471f-a8d0-b5d104b11e17',
#   '1d8d9307-7171-4652-a369-02892c14c1e0',
#   '08b68795-1cf0-4663-93dc-adafa0481a85',
#   '16d8d5a0-d0ab-4aa1-9496-f7690f2f0c0a',
#   '799d9611-460b-4ee6-bd74-8bd1277f00f1',
#   '1f22dabd-e230-4fbb-b141-1c1b056f0193',
#   '7b65df71-f844-4883-a90e-9bf5068789cb',
#   '574e3cf6-b857-450d-822c-672f46f55948',
#   '541ae49d-9e84-4e02-b4ff-dbd333e1557e',
#   'f1c990a7-0b75-43df-b651-9041f79b6166',
#   '58def63d-1b56-47af-a8cd-503618032b94',
#   '233a8395-fe90-4f5f-abe5-191f1bd25620',
#   'dfc50e92-986c-40e7-a781-da70e978ab19',
#   'f599035c-b836-46cc-a9d2-026d0d83e8d5',
#   'd32c7a91-def4-4248-beb9-5fee7067d405',
#   '12af3baa-c80a-4fbd-8b6d-fce4feb213fe',
#   'efda4509-6e93-4e69-a003-431e739879f6',
#   '0fbd644f-8c24-4231-b105-3596c67fd8ca',
#   '4d071954-ac72-47de-b9a5-c2a1402bd66b',
#   'd176dae0-c183-4618-8d2f-1b8eaf62ccae',
#   'e4859f48-93f5-47ec-b209-b66fe081c9db',
#   '510e34f2-9d8e-4fbc-bfb0-8d7b17fffe0f',
#   'bb6f66a4-5679-47fd-b912-2e22a0f7c66b',
#   'c69596ab-a90a-42ae-9a9e-340a38ba6415',
#   '8147b484-1fa0-4515-9c1e-50f05c1a9f9c',
#   'fad7e285-99b2-4767-9c3f-e75cf5bc1f38',
#   '92d0ff2f-5efc-40de-a2c6-81de3d166ade',
#   '3eacdd76-469d-4276-9328-82dcdea0c129',
#   '9c10b45f-4b87-457d-a08a-eec1ee5afcc6',
#   'd840ab0e-7eff-48f8-94c2-a869e04dde54',
#   '0fc28b04-f25a-41bc-a7af-20e3d39112b0',
#   '16da5318-ac92-4842-a50a-f3a13af70965',
#   '5ceb05a9-abee-4b43-a901-ea1c95642747',
#   '4959d8ea-cf28-4878-aa81-488c31453d09',
#   '3c9fe7ba-06b0-49c7-b7af-6643840b1667',
#   '391721f9-f8e2-4d75-a819-a4b9f3b3b518',
#   '71201b95-4724-4410-8509-fe390fcdf8a4',
#   '397f4d36-700a-469a-8b60-2b58408987ee',
#   'dad10372-33a2-4af7-82b0-680f4a384f73',
#   '56b6a62a-918f-4085-9164-9165bce67667',
#   '0db4b2b2-f29f-4a90-ad9e-d8c15832319b',
#   '70fc1866-7f98-41fd-9c02-2b7ae036ec98',
#   '4289069b-96a7-49b5-ae66-6cb256b81853',
#   '76a25d03-9946-40d2-a187-5b3719e98abd',
#   'a4ae1cf5-315f-40d4-b544-e83f4a6ee68c',
#   'a06fe82e-e3d9-4bc3-ae77-106a2b3d5029',
#   '278bd195-3c2e-457c-b0e7-7498685fce89',
#   'bfeb5306-533c-47d4-b584-1d87436b2b9c',
#   '3d4999a4-e25f-4603-a1c8-46d49b448acc',
#   '5f2aaee1-ede3-418a-9071-890fad66bb3f',
#   '952e18ec-200c-4c54-b001-640df0561c75',
#   '691cb685-93fd-40fe-a730-0fec0912ef10',
#   '98fe191a-12e4-4268-a6a9-db4455a84eb5',
#   'beffe0f1-16ae-4773-8c9e-1debdb346d98',
#   '6257db9a-1265-4cc8-8904-60414ed76733',
#   '7d02cd33-2c27-4899-a19f-feddb4c8a2a3',
#   '28194fee-4b35-4a11-9193-cbc34b87f0bb',
#   '706b3521-9f30-400a-b410-fe90478cb9dd',
#   'dd0c6986-f8c3-4820-a13d-3e0d8e4d0bed',
#   '7eb0adf3-38cc-4f2a-b4b4-b76a980d2b25',
#   'df5e1090-ed15-4c50-8aa1-98e809617db6',
#   'c5428d58-8c05-4eb8-a829-cb6e19b4d9a4',
#   '396da51e-63bc-4d04-ae86-d9183b4c296d',
#   '926e670f-7fe9-4b21-8277-3b385dd3fe17',
#   '9fc26257-cfc6-484b-8881-983e456d9f38',
#   '9e885ebf-e5c4-4486-97c8-ed7ccd2a6592',
#   'e4316567-df04-4b86-86d1-15bae30ac397',
#   '837b98e3-cc85-4ddb-9060-2b6fb1908597',
#   'adf10346-b2c4-478c-b774-613827ea0900',
#   'a8c91e8a-3aab-4dd6-8032-22afe7ddb4cd',
#   'a3e11ea4-7dd5-4fcf-a5be-d9c8748575d6',
#   'b431d79a-46dc-4fda-aa95-5f1d48ecfa61',
#   '7a74813b-140f-46aa-b952-5c7e3a08d734',
#   '29fcd3ec-0921-4dbf-bef7-814540d0647d',
#   'e9679ee0-cac8-4eab-a14f-99774ff0065b',
#   '7d07a7a0-5460-48ae-a08d-20add35b78a4',
#   'a50eb0d8-6a92-454e-8035-aa03b4e5a5bd',
#   '3f49a561-1c6a-40d8-8ab8-a8c7c23d2de4',
#   '7561d77f-8459-49b9-a5f8-994528c5c44c',
#   '3988e791-a731-42a9-ab11-ddcedf7f3e8d',
#   '42dca26d-4527-4625-b410-eafc54b691ee',
#   '5b825984-ac2d-4e28-bf9e-61c028c20b54',
#   '973e4fc0-f309-404f-a989-05339259cbb3',
#   'bba0d44e-74b7-49a8-ac53-b4cee66f64bf',
#   'a982ec4d-1791-4f89-a6a0-d1682bf56b65',
#   '5b222e3b-22d9-4782-92f7-b68d043b2d52',
#   'b5be8c60-5d7b-4a24-90cd-47188c93cb29',
#   '7f1307bd-42fb-4213-972f-d6f9250b3e6c',
#   'd78bfd18-b1e3-40e9-ad09-19de648f766a',
#   'f16be1c6-8feb-4175-a831-883a3dfa2d49',
#   '06bebc70-2ff6-42d5-8420-772170df91bb',
#   'c6dd277b-9d21-4ffe-a9f5-b8f4e9c5062a',
#   'cfa365e3-b20d-43a9-9496-a2631956e3ef',
#   'bea59803-926a-408c-b5dc-c54972a069a1',
#   'bdbdbcf3-dc63-450e-9f60-be09ed0e1836',
#   'fa1a24d6-fd0b-40ee-a728-45afbd4de7f1',
#   '0b7a9226-c3c0-4d89-8467-50e2fe71f53d',
#   '9d5c4965-7776-44f8-ace7-52c417673755',
#   '961bb4eb-5cff-423b-b6f1-d491598fa5ca',
#   'ad712681-89bb-42a1-87c1-fa83342e5bf8',
#   'f38825b2-b800-4ce2-a523-6f16130794b7',
#   'a27fb2ae-958f-45ef-b0c8-7de9bcab8aff',
#   'c797d81f-341d-4595-81b0-a57f2c6b542f',
#   '99f6ee9d-e988-4f58-84da-f671b0fb4e94',
#   'c6a26c11-9ffb-41a4-8c18-62660833185c',
#   '843e4ee3-4ce1-4556-a7d9-ff07a7832655',
#   'f09b57b6-2ca4-48c2-b014-64352763bbb6',
#   '2357aa15-cf90-4d93-b1f4-e0103ad3c521',
#   '0549efdf-cee8-4e1d-95e0-99b85ae082ab',
#   '65789c0f-06ff-4a81-94a7-cbe188056d9f',
#   'c621eb82-6f4b-4b5e-9595-43dd90e406ee',
#   '3c0288ac-5363-4ac6-827c-b5c101383da0',
#   '059fa803-a6b0-4349-97bb-4c93a67d415a',
#   'cee52784-ac6b-4608-ab97-ea85cda55a21',
#   '3778002d-219f-4121-bbc2-596424f54d1f',
#   'dc063e93-e2ba-4f0a-a4e3-2a4e8421e53c',
#   'ecfc6cb5-fbce-4281-a4dc-dde193449175',
#   'a6a9a469-7322-4bdc-899d-18066212efa4',
#   '307a45d3-9ad7-45e3-804e-c6bfa14a69ad',
#   '48f780b2-2ec7-409c-a0d0-64a93c7b0e8d',
#   '722a8391-589a-4ea4-8182-79c04a0a9048',
#   '54a908f5-a2db-41c8-a605-3651192882ed',
#   '06584f5b-a981-40b3-8118-4fe15be102f4',
#   '4684f75f-1cdc-4040-8c68-8175c1edc0a6',
#   '5d944385-ed61-463f-b48e-04d8f7c66248',
#   'e41f1d19-627d-44c1-ab41-d174aecf1de4',
#   '43edf77c-3d4a-4918-99c0-d7c6826228de',
#   '59eac58f-cd37-42f8-a6e3-608ffa06919c',
#   'aab0e3bc-108d-404a-b1e6-59e5d257abdc',
#   '386281ab-370c-4e39-821d-32cce78822f2',
#   'af69cbd1-38ce-4096-b932-838c0803df7f',
#   '80908b8b-7789-4309-8234-f33eca6ef9bf',
#   'c45f0faa-057a-4a55-828f-2b7a0d4895d2',
#   'da406e39-607e-45a3-9577-11c18ce4fdc3',
#   '3f8899b6-dde3-49db-ae9d-d01b976f1d17',
#   '97b1de63-2a55-46e2-8c90-907a111b7e95',
#   'd208e1b9-e6a6-4d1d-a346-696f5fedd2da',
#   'c377f421-3ce9-41cc-88fa-8dfa2eda5f17',
#   '82ac98ac-7e09-47da-9e3d-3cbb6815b1e2',
#   'af79ee9d-a758-41df-b3e4-1e681488e11c',
#   '31c83df1-f709-4db9-bae7-12a686c550c8',
#   '470d85b3-e10d-45d4-bcf8-d3c2ffa6da6c',
#   'ef5edb9d-747d-48af-8238-cd693290d504',
#   '1af252c0-b087-4755-841f-6e3fdc8084bd',
#   '4a8035e6-f084-4da6-aaa8-4fa911b10059',
#   '399325f8-28b0-470d-9da6-23e9fe555656',
#   '9bff4207-e272-45a8-b4a9-4d4cb37cc3d8',
#   '53b30695-a964-4fcf-8513-6f174bb9e298',
#   '7e88d844-25bc-4d2d-9a5a-3d9f383df46c',
#   '1acad14a-bf5f-4470-9063-abe472e4cc43',
#   '3a433edf-19e3-4226-b8f7-6cb1bf16dc56',
#   'd6705cfd-1945-433a-a494-26a50cb369ec',
#   '3e3b31a7-d9c1-4196-abd3-0ce04d5bff4e',
#   'ac4efc4e-2f47-4752-a5d5-fbdb2e9b323b',
#   '79ca632c-904e-41ca-9452-83e85525d945',
#   '75f5fbb9-4a0f-4f0d-b6a7-7ff08ef3fbc8',
#   '33f640a7-0cd8-4cf9-a677-a608ce028032',
#   '9ac2978c-dee7-4c53-8754-e02832f4427b',
#   'e6a9c67c-6642-4979-84cc-892568309cfd',
#   '172261bb-63e6-4f9a-8332-39bcc16c9d23',
#   '051f9619-f53a-4ceb-b05e-7f35fb911d36',
#   '40ec7003-32c5-42d5-b7a2-c70e4eee5eda',
#   '006d9d56-c751-47ed-9c9b-2bd505080679',
#   '4483f9d6-2f52-430b-ba07-3e04512143a7',
#   '12b56d0c-4c85-4d1d-9cef-745d7900f43b',
#   '05fe6585-5f87-4117-8a6d-548b688a4ceb',
#   'ab4dc0cb-25c5-484a-827b-118a65e170a2',
#   '7810c4ea-2aa8-4792-b106-4f74cb075414',
#   '334bffc8-e43d-4955-a3f2-8d5f3cef6e75',
#   '7e21c53e-fa80-4981-8e67-b60f27ff5f05',
#   '5b070028-e330-4940-9c3b-962931baba20',
#   'bcb255ea-8b6b-4f9b-a313-8b609255b8dd',
#   'ab059146-db2f-4886-92e7-e906aa173d79',
#   'd9b85809-27c6-4a44-b07f-1df8f5b432d0',
#   'c2635d6f-b773-4e11-b40f-a1a16e31a4e1',
#   '03935e2a-55fa-46a1-b3d4-b86800867ccc',
#   '9787a5f4-442b-41a0-9fc8-9ac4167fcbf4',
#   '47417f92-f419-4eb0-89c7-3842eea95a60',
#   'c3bedb3b-fab2-463e-9fb5-848c37d34ed4',
#   'faa70910-2a9d-4561-a08b-48d9693abef7',
#   '7567a89b-4c3c-4292-88eb-bf1453884821',
#   '27f050bc-9729-4c0a-a3c6-bc876f29129b',
#   '03184ffb-6f05-4287-81cf-a867bf9955bd',
#   '8d2fc0ed-8fb7-4274-a4e6-746f07f2a52f',
#   '98db9e1a-3c92-46ff-9646-4b82775f3573',
#   'f7736846-c2d3-40af-ad49-c1d7d6c99701',
#   '106e9ce2-7016-483c-8d43-b01514a5707d',
#   '4306c477-e818-497a-9d04-664c154b9d40',
#   '186381a0-8cc7-445e-b029-2a863419346f',
#   'db936e34-453c-4371-90bf-a5d5405589bb',
#   '6353b87c-aab8-416f-ae3f-4da6114d3b5c',
#   '9078d3a2-26a7-498a-b9e9-5c6639af58b8',
#   'a47a0407-89e5-4a8e-b011-201b7bee9171',
#   'fda572f4-9a8a-4b23-ad16-abce54d3b464',
#   'ab2a9d82-7ddd-4afb-8d8d-ea47dbeff14e',
#   'ea7c4385-36b6-40f8-a5e7-fb7c7e4788d2',
#   '10a1b66b-96f5-4c3d-8645-de5e91b2b284',
#   '23dcf0f3-41c1-4c31-be28-da62d27f44e4',
#   'ec82a0a5-e8bd-44cf-b4b0-ff39df475dac',
#   'a209deac-7c45-424e-a340-fde190e83e26',
#   '63616d8c-9a88-4a32-831a-fd19c6e45838',
#   'a5fea5ac-f74d-46f7-ab33-3bfcaf86c332',
#   'ad9c37fc-88a7-4b4f-9d8e-64ef56f8a008',
#   '6bcb8871-e8ed-4411-b26a-aa80d1a771f0',
#   '4bf2e432-a165-4239-ad61-7048ede33c85',
#   '84ffc88b-6ddd-498d-9bff-f3857db53fa6',
#   '5c8e6432-0e01-44dc-bc10-a946715ecfc1',
#   '410a994b-00f4-408d-bbdb-27fa3d6b92b8',
#   '59e5ff03-34cd-466d-9e8f-c3dba878a112',
#   '728dbd9a-8216-4c7f-9fdb-d72b2bfd252b',
#   '9e0ff142-ef6a-488f-8924-5e51f269a822',
#   'e8291314-fd82-4214-b243-b15f56a8ea9d',
#   '07bd0880-3f95-4485-bb23-e3edb937c32e',
#   '6336e887-2c00-488c-97f5-34f09efc4ba2',
#   '80972961-3531-4ac6-882c-20b71b7bd501',
#   '0d54b1e3-43f4-454e-8db3-27bd59e5ee99',
#   '62cf601b-6c50-4c1a-88f5-bb34c4a73627',
#   'e4df88ad-d646-491d-b76f-7116ad3ca726',
#   '344e4822-159c-444f-b63e-807dfa67bc72',
#   'f7fe2347-f3f2-44b3-932a-d476227619bb',
#   'ba8fe0f5-38a2-4c1d-9eaa-a2d4d8e049fa',
#   '3e91eaa3-d813-4205-80e7-76d06a0642f1',
#   'df4e263f-bf04-40e3-a539-9ab121b72c6f',
#   '7a27bc48-ca9c-4be3-864e-592333fa7be8',
#   '1af94553-e2e9-441f-ab67-9bc19c71fbbf',
#   '31aa9030-533e-47c5-86c9-18cfbddd72bb',
#   'e45cf643-b83b-46bd-a1f6-453b9da1d4ae',
#   'aa35d16b-c2e6-4a1e-b23d-7d4fd7f644c2',
#   '73c193fd-aee7-48df-80da-a08fdaf68ef8',
#   '253cdcef-2aea-4d42-bf40-023a2c67310f',
#   'd73e6fcf-8aa1-4156-9130-2e616094a592',
#   '145aa86c-a182-4759-9b56-9beb0343a3c6',
#   'cdd519cb-9902-4b99-b0b7-3176032f298f',
#   '6fb7934b-e6ae-4ab1-bdde-95d204a35338',
#   'ce2b5e5f-67fd-4b35-a321-d5e6d3ad3578',
#   'c88d5c9f-a240-4152-9478-ba6ed71e6987',
#   'eeaf4337-e231-4eb2-b726-acc82138573f',
#   '2986f3ef-2b89-40c8-835a-89ea00005dd7',
#   '7831be00-abce-40f0-bc20-cbafd04febf1',
#   '05c1d382-b392-4882-97d8-2103fc7ac970',
#   '0c24e7b5-b3ad-43e0-bb2d-880373a2cddb',
#   '28e9b8b5-a0d5-4adc-90c8-495df5ebf427',
#   '0a809b96-ca46-4da9-9632-6c0f4111c4b8',
#   'ce04464e-963e-424c-85f5-d32f2cc9a9de',
#   'c7da6d82-7678-41ef-802e-008829877ec1',
#   'ce312c7a-8ae8-4251-82f6-d5d12638734b',
#   '83e7e462-128d-4d95-a9e7-24308c6ff754',
#   '16aba627-7363-4d27-a7eb-67f3efa74d37',
#   ...],
#  'embeddings': None,
#  'documents': ['저작자표시-비영리-변경금지 2.0 대한민국 \n이용자는 아래의 조건을 따르는 경우에 한하여 자유롭게 \nl 이 저작물을 복제, 배포, 전송, 전시, 공연 및 방송할 수 있습니다.  \n다음과 같은 조건을 따라야 합니다: \nl 귀하는, 이 저작물의 재이용이나 배포의 경우, 이 저작물에 적용된 이용허락조건\n을 명확하게 나타내어야 합니다.  \nl 저작권자로부터 별도의 허가를 받으면 이러한 조건들은 적용되지 않습니다.  \n저작권법에 따른 이용자의 권리는 위의 내용에 의하여 영향을 받지 않습니다. \n이것은 이용허락규약(Legal Code)을 이해하기 쉽게 요약한 것입니다.  \nDisclaimer \n \n  \n  \n저작자표시. 귀하는 원저작자를 표시하여야 합니다. \n비영리. 귀하는 이 저작물을 영리 목적으로 이용할 수 없습니다. \n변경금지. 귀하는 이 저작물을 개작, 변형 또는 가공할 수 없습니다.',
#   '공학박사학위논문 \n \n기포동역학을 이용한 선박 추진기 \nCIS 해석 시스템 개발 \n \nDevelopment of Cavitation Inception Speed analysis system  \nfor ship propellers using bubble dynamics  \n \n \n \n2024년 2월 \n \n \n \n서울대학교 대학원 \n조선해양공학과 \n정승진',
#   'i \n초록 \n \n기포동역학을 이용한 선박 추진기 \nCIS 해석 시스템 개발 \n    \n \n선박은 현대사회에서 매우 핵심적인 역할을 담당하며, 크게 상선과 \n해군 함정(군함)으로 구분된다. 상선은 다양한 상품과 자원을 국가 간에 \n이동시키며, 상선의 효율적인 운항은 국제 무역 활성화에 있어서 \n불가결한 요소이다. 해군 함정은 국가의 국방 및 안보를 책임지며, \n다양한 해양 작전과 임무를 수행하는 핵심 자원이며, 국방력을 강화하는 \n데 중대한 역할을 한다. 선박으로부터 발생하여 수중으로 전파되는 \n소음을 수중방사소음(Underwater Radiated Noise; URN)으로 정의하며, \n상선은 국제기구의 소음규제 만족, 함정은 함의 생존성 향상을 위해 \n저감해야만 한다. 수중방사소음의 증가를 일으키는 요인 중 하나로 \n추진기 소음이 있다. 특히, 추진기 캐비테이션이 발생할 경우 추진기 \n소음이 급격히 증가하기 때문에, 상선의 수중방사소음 수준이 매우',
#   '추진기 소음이 있다. 특히, 추진기 캐비테이션이 발생할 경우 추진기 \n소음이 급격히 증가하기 때문에, 상선의 수중방사소음 수준이 매우 \n증가하고, 함정의 경우 생존성이 매우 취약해진다. 이에, 해군에서는 \n캐비테이션의 발생과 관련하여 캐비테이션 초생 선속(Cavitation Inception',
#   'ii \nSpeed; CIS)의 추진기 평가 지수를 도입하여 관리하고 있다.  \n본 논문에서는 선박 추진기의 캐비테이션 초생 선속을 평가할 수 \n있는 해석기법 및 시스템을 구축하였다. 기포동역학(Bubble dynamics)의 \n주요 지배방정식을 이용하여 일련의 해석 시스템을 정립하였으며, \n다양한 형상의 날개 및 추진기에 대한 해석을 수행함으로써 그 효용성을 \n입증하였다. 캐비테이션의 초생을 예측하기 위하여, 다양한 캐비테이션 \n수 조건을 상정하여 해석을 수행하였다. 캐비테이션 수는 정수압 조건과 \n속력 조건의 비율을 의미하는 무차원 수로, 본 연구에서는 정수압을 \n조정함으로써 캐비테이션 수 조건을 다양화하였다. 먼저 간단한 형상인 \n타원형 날개(Elliptic wing)에 대한 캐비테이션 초생 선속 해석 결과를 \n도출하고, 이를 실험 계측 결과와 비교하여 개발한 해석 시스템을 \n검증하였다. 검증된 시스템을 이용하여 잠수함(Submarine)의 다양한',
#   '도출하고, 이를 실험 계측 결과와 비교하여 개발한 해석 시스템을 \n검증하였다. 검증된 시스템을 이용하여 잠수함(Submarine)의 다양한 \n추진기(Propeller)에 대한 해석을 수행하여, 추진기 별 캐비테이션 초생 \n선속 값을 비교하고, 설계 변수에 따른 지연 효과를 해석 시스템을 \n이용하여 확인하였다. 수상함(Surface ship) 모델 및 추진기 형상을 \n선정하여 캐비테이션 초생 선속 예측을 수행하였으며, 실험 관측 결과와 \n잘 일치하는 결과를 도출하였다. \n또한, 선박 추진기의 캐비테이션 초생 선속을 지연하기 위한 와류발\n생기(Vortex generator)를 설계하여, 그 효과를 정량적으로 분석하였다. 선\n박의 선저면에 부착하는 형태의 부가물인 와류발생기를 설치하여, 추진\n기로의 유입류 개선효과를 전산유체역학 해석을 통해 확인하고, 개발한',
#   'iii \n캐비테이션 초생 선속 해석 시스템을 이용하여 설치에 의한 지연 효과를 \n비교하여 분석하였다. \n \n주요어: 선박 추진기, 날개 끝 보텍스 캐비테이션,  \n캐비테이션 초생 선속, 캐비테이션 핵, 기포동역학, \n와류발생기 \n \n학  번: 2017-26915',
#   'iv \n목 차 \n \n1. 서론 .................................................................... 1 \n1.1. 연구배경 및 내용 ................................................................. 1 \n1.2. 캐비테이션의 개요 ................................................................ 6 \n1.2.1. 캐비테이션 일반 ................................................................................. 6 \n1.2.2. 추진기 캐비테이션의 최초 보고 ..................................................... 10',
#   '1.2.2. 추진기 캐비테이션의 최초 보고 ..................................................... 10 \n1.2.3. 캐비테이션의 종류 ............................................................................ 12 \n1.2.4. 날개 끝 보텍스 캐비테이션(Tip Vortex Cavitation; TVC) ........... 16 \n1.2.5. 캐비테이션 소음 ............................................................................... 19 \n1.3. 현행 캐비테이션 초생 선속 판정 방식 ............................. 21 \n1.3.1. 육안관측을 통한 VCIS 판정 ............................................................ 22',
#   '1.3.1. 육안관측을 통한 VCIS 판정 ............................................................ 22 \n1.3.2. DEMON을 이용한 ACIS 판정 .......................................................... 24 \n1.3.3. 선속 당 소음증가율을 이용한 ACIS 판정...................................... 30 \n1.4. 논문구성 .............................................................................. 33 \n2. 캐비테이션 초생 선속 해석 시스템 개발 ....... 35 \n2.1. 전산유체역학을 이용한 수치점성유동해석 ........................ 36',
#   '2. 캐비테이션 초생 선속 해석 시스템 개발 ....... 35 \n2.1. 전산유체역학을 이용한 수치점성유동해석 ........................ 36 \n2.2. 기포동역학(Bubble dynamics) ............................................. 39 \n2.2.1. 캐비테이션 핵(Cavitation nuclei) .................................................... 39 \n2.2.2. Rayleigh-Plesset 방정식 ................................................................... 42',
#   'v \n2.2.3. 기포 이동 방정식(Bubble motion equation)................................... 47 \n2.2.4. 캐비테이션 소음원 모델링 .............................................................. 50 \n2.2.5. 캐비테이션 수(Cavitation number) ................................................. 54 \n2.3. 캐비테이션 초생 선속 해석 시스템 ................................... 57 \n2.4. 타원형날개에 대한 캐비테이션 초생 선속 해석 ............... 64 \n2.4.1. 수중익에 대한 캐비테이션 초생 선속 해석 기법 ........................ 64',
#   '2.4.1. 수중익에 대한 캐비테이션 초생 선속 해석 기법 ........................ 64 \n2.4.2. 타원형날개 형상 ............................................................................... 67 \n2.4.3. 타원형날개에 대한 전산유체역학 해석.......................................... 69 \n2.4.4. 타원형날개에 대한 캐비테이션 초생 선속 해석 .......................... 73 \n3. 추진기에 대한 캐비테이션 초생 선속 해석 ... 86 \n3.1. 잠수함 추진기에 대한 캐비테이션 초생 선속 해석 .......... 87 \n3.1.1. 잠수함 추진기에 대한 캐비테이션 초생 선속 해석 기법 ........... 87',
#   '3.1. 잠수함 추진기에 대한 캐비테이션 초생 선속 해석 .......... 87 \n3.1.1. 잠수함 추진기에 대한 캐비테이션 초생 선속 해석 기법 ........... 87 \n3.1.2. DARPA Suboff 잠수함 형상 ............................................................ 90 \n3.1.3. 잠수함 추진기 형상 .......................................................................... 92 \n3.1.4. 잠수함에 대한 전산유체역학 해석 ............................................... 101 \n3.1.5. 잠수함 추진기에 대한 캐비테이션 초생 선속 해석 ................... 121 \n3.2. 수상함 추진기에 대한 캐비테이션 초생 선속 해석 ........ 136',
# ...
#    'title': ''},
#   {'subject': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'author': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'title': '',
#    'trapped': '',
#    'producer': 'ezPDF Builder 2006',
#    'total_pages': 247,
#    'format': 'PDF 1.7',
#    'keywords': '',
#    'modDate': "D:20080821135700+09'00'",
#    'page': 53,
#    'creator': 'ezPDF Builder 2006'},
#   {'creator': 'ezPDF Builder 2006',
#    'total_pages': 247,
#    'title': '',
#    'producer': 'ezPDF Builder 2006',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'keywords': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'modDate': "D:20080821135700+09'00'",
#    'trapped': '',
#    'subject': '',
#    'author': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'format': 'PDF 1.7',
#    'page': 54,
#    'file_path': './data\\doc_CIS_URN_250903.pdf'},
#   {'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'total_pages': 247,
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'creationDate': "D:20080820165432+09'00'",
#    'format': 'PDF 1.7',
#    'keywords': '',
#    'title': '',
#    'modDate': "D:20080821135700+09'00'",
#    'author': '',
#    'page': 54,
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'subject': '',
#    'trapped': '',
#    'creator': 'ezPDF Builder 2006',
#    'producer': 'ezPDF Builder 2006'},
#   {'keywords': '',
#    'subject': '',
#    'total_pages': 247,
#    'title': '',
#    'modDate': "D:20080821135700+09'00'",
#    'creationDate': "D:20080820165432+09'00'",
#    'producer': 'ezPDF Builder 2006',
#    'page': 55,
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'format': 'PDF 1.7',
#    'creator': 'ezPDF Builder 2006',
#    'trapped': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'author': ''},
#   {'keywords': '',
#    'title': '',
#    'trapped': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'total_pages': 247,
#    'page': 56,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'producer': 'ezPDF Builder 2006',
#    'subject': '',
#    'format': 'PDF 1.7',
#    'author': '',
#    'modDate': "D:20080821135700+09'00'",
#    'creator': 'ezPDF Builder 2006'},
#   {'total_pages': 247,
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'creator': 'ezPDF Builder 2006',
#    'title': '',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'format': 'PDF 1.7',
#    'keywords': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'trapped': '',
#    'producer': 'ezPDF Builder 2006',
#    'modDate': "D:20080821135700+09'00'",
#    'subject': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'page': 56,
#    'author': ''},
#   {'producer': 'ezPDF Builder 2006',
#    'subject': '',
#    'format': 'PDF 1.7',
#    'keywords': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'trapped': '',
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'page': 57,
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'title': '',
#    'creator': 'ezPDF Builder 2006',
#    'total_pages': 247,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'author': ''},
#   {'author': '',
#    'page': 58,
#    'keywords': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'subject': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'trapped': '',
#    'modDate': "D:20080821135700+09'00'",
#    'title': '',
#    'format': 'PDF 1.7',
#    'total_pages': 247,
#    'creator': 'ezPDF Builder 2006',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'producer': 'ezPDF Builder 2006'},
#   {'producer': 'ezPDF Builder 2006',
#    'page': 59,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'modDate': "D:20080821135700+09'00'",
#    'total_pages': 247,
#    'format': 'PDF 1.7',
#    'trapped': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'title': '',
#    'subject': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'author': '',
#    'keywords': '',
#    'creator': 'ezPDF Builder 2006'},
#   {'source': './data\\doc_CIS_URN_250903.pdf',
#    'subject': '',
#    'author': '',
#    'total_pages': 247,
#    'creationDate': "D:20080820165432+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'title': '',
#    'modDate': "D:20080821135700+09'00'",
#    'creator': 'ezPDF Builder 2006',
#    'trapped': '',
#    'producer': 'ezPDF Builder 2006',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'format': 'PDF 1.7',
#    'page': 59,
#    'keywords': ''},
#   {'keywords': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'trapped': '',
#    'producer': 'ezPDF Builder 2006',
#    'modDate': "D:20080821135700+09'00'",
#    'subject': '',
#    'total_pages': 247,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'page': 60,
#    'title': '',
#    'format': 'PDF 1.7',
#    'author': '',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf'},
#   {'subject': '',
#    'creator': 'ezPDF Builder 2006',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'title': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'modDate': "D:20080821135700+09'00'",
#    'format': 'PDF 1.7',
#    'author': '',
#    'total_pages': 247,
#    'creationDate': "D:20080820165432+09'00'",
#    'page': 61,
#    'trapped': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'producer': 'ezPDF Builder 2006',
#    'keywords': ''},
#   {'total_pages': 247,
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'keywords': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationDate': "D:20080820165432+09'00'",
#    'producer': 'ezPDF Builder 2006',
#    'trapped': '',
#    'title': '',
#    'creator': 'ezPDF Builder 2006',
#    'format': 'PDF 1.7',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'page': 61,
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'subject': '',
#    'author': ''},
#   {'subject': '',
#    'page': 62,
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'total_pages': 247,
#    'creationDate': "D:20080820165432+09'00'",
#    'trapped': '',
#    'format': 'PDF 1.7',
#    'title': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'modDate': "D:20080821135700+09'00'",
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'creator': 'ezPDF Builder 2006',
#    'producer': 'ezPDF Builder 2006',
#    'author': '',
#    'keywords': ''},
#   {'format': 'PDF 1.7',
#    'title': '',
#    'total_pages': 247,
#    'trapped': '',
#    'creator': 'ezPDF Builder 2006',
#    'page': 62,
#    'author': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'producer': 'ezPDF Builder 2006',
#    'subject': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'keywords': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00'},
#   {'keywords': '',
#    'page': 63,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'trapped': '',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'creator': 'ezPDF Builder 2006',
#    'subject': '',
#    'modDate': "D:20080821135700+09'00'",
#    'total_pages': 247,
#    'creationDate': "D:20080820165432+09'00'",
#    'title': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'format': 'PDF 1.7',
#    'author': '',
#    'producer': 'ezPDF Builder 2006',
#    'moddate': '2008-08-21T13:57:00+09:00'},
#   {'format': 'PDF 1.7',
#    'creator': 'ezPDF Builder 2006',
#    'subject': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'author': '',
#    'trapped': '',
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'total_pages': 247,
#    'keywords': '',
#    'page': 64,
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'producer': 'ezPDF Builder 2006',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationDate': "D:20080820165432+09'00'",
#    'title': ''},
#   {'subject': '',
#    'title': '',
#    'page': 64,
#    'creationDate': "D:20080820165432+09'00'",
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'producer': 'ezPDF Builder 2006',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'trapped': '',
#    'author': '',
#    'format': 'PDF 1.7',
#    'total_pages': 247,
#    'modDate': "D:20080821135700+09'00'",
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'keywords': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf'},
#   {'author': '',
#    'producer': 'ezPDF Builder 2006',
#    'title': '',
#    'total_pages': 247,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'format': 'PDF 1.7',
#    'creator': 'ezPDF Builder 2006',
#    'page': 65,
#    'subject': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'keywords': '',
#    'modDate': "D:20080821135700+09'00'",
#    'trapped': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00'},
#   {'creator': 'ezPDF Builder 2006',
#    'format': 'PDF 1.7',
#    'creationDate': "D:20080820165432+09'00'",
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'page': 65,
#    'subject': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'trapped': '',
#    'total_pages': 247,
#    'title': '',
#    'producer': 'ezPDF Builder 2006',
#    'modDate': "D:20080821135700+09'00'",
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'author': '',
#    'keywords': ''},
#   {'format': 'PDF 1.7',
#    'page': 66,
#    'producer': 'ezPDF Builder 2006',
#    'total_pages': 247,
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'subject': '',
#    'trapped': '',
#    'author': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'modDate': "D:20080821135700+09'00'",
#    'creator': 'ezPDF Builder 2006',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'keywords': '',
#    'title': ''},
#   {'source': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'modDate': "D:20080821135700+09'00'",
#    'format': 'PDF 1.7',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'creationDate': "D:20080820165432+09'00'",
#    'author': '',
#    'page': 67,
#    'keywords': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'producer': 'ezPDF Builder 2006',
#    'title': '',
#    'total_pages': 247,
#    'trapped': '',
#    'subject': ''},
#   {'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'keywords': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'trapped': '',
#    'creator': 'ezPDF Builder 2006',
#    'page': 68,
#    'creationDate': "D:20080820165432+09'00'",
#    'author': '',
#    'total_pages': 247,
#    'modDate': "D:20080821135700+09'00'",
#    'subject': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'format': 'PDF 1.7',
#    'producer': 'ezPDF Builder 2006',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'title': ''},
#   {'creationdate': '2008-08-20T16:54:32+09:00',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'producer': 'ezPDF Builder 2006',
#    'keywords': '',
#    'format': 'PDF 1.7',
#    'trapped': '',
#    'author': '',
#    'creator': 'ezPDF Builder 2006',
#    'title': '',
#    'total_pages': 247,
#    'page': 68,
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'subject': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'modDate': "D:20080821135700+09'00'"},
#   {'keywords': '',
#    'format': 'PDF 1.7',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'subject': '',
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'creator': 'ezPDF Builder 2006',
#    'total_pages': 247,
#    'trapped': '',
#    'title': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'author': '',
#    'producer': 'ezPDF Builder 2006',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creationDate': "D:20080820165432+09'00'",
#    'page': 69},
#   {'page': 70,
#    'format': 'PDF 1.7',
#    'author': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'creationDate': "D:20080820165432+09'00'",
#    'subject': '',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'keywords': '',
#    'producer': 'ezPDF Builder 2006',
#    'modDate': "D:20080821135700+09'00'",
#    'trapped': '',
#    'title': '',
#    'total_pages': 247,
#    'moddate': '2008-08-21T13:57:00+09:00'},
#   {'creator': 'ezPDF Builder 2006',
#    'format': 'PDF 1.7',
#    'total_pages': 247,
#    'producer': 'ezPDF Builder 2006',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'modDate': "D:20080821135700+09'00'",
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'trapped': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'keywords': '',
#    'title': '',
#    'subject': '',
#    'page': 71,
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationDate': "D:20080820165432+09'00'",
#    'author': ''},
#   {'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'trapped': '',
#    'title': '',
#    'producer': 'ezPDF Builder 2006',
#    'creationDate': "D:20080820165432+09'00'",
#    'total_pages': 247,
#    'format': 'PDF 1.7',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'author': '',
#    'keywords': '',
#    'page': 72,
#    'modDate': "D:20080821135700+09'00'",
#    'subject': ''},
#   {'keywords': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'modDate': "D:20080821135700+09'00'",
#    'producer': 'ezPDF Builder 2006',
#    'page': 72,
#    'creationDate': "D:20080820165432+09'00'",
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'author': '',
#    'creator': 'ezPDF Builder 2006',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'trapped': '',
#    'subject': '',
#    'format': 'PDF 1.7',
#    'title': '',
#    'total_pages': 247},
#   {'source': './data\\doc_CIS_URN_250903.pdf',
#    'subject': '',
#    'total_pages': 247,
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'trapped': '',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'creator': 'ezPDF Builder 2006',
#    'author': '',
#    'keywords': '',
#    'modDate': "D:20080821135700+09'00'",
#    'title': '',
#    'producer': 'ezPDF Builder 2006',
#    'creationDate': "D:20080820165432+09'00'",
#    'page': 73,
#    'format': 'PDF 1.7'},
#   {'creationDate': "D:20080820165432+09'00'",
#    'keywords': '',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'author': '',
#    'trapped': '',
#    'creator': 'ezPDF Builder 2006',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'producer': 'ezPDF Builder 2006',
#    'modDate': "D:20080821135700+09'00'",
#    'subject': '',
#    'page': 73,
#    'total_pages': 247,
#    'title': '',
#    'format': 'PDF 1.7'},
#   {'title': '',
#    'creationDate': "D:20080820165432+09'00'",
#    'page': 74,
#    'subject': '',
#    'creationdate': '2008-08-20T16:54:32+09:00',
#    'total_pages': 247,
#    'moddate': '2008-08-21T13:57:00+09:00',
#    'format': 'PDF 1.7',
#    'creator': 'ezPDF Builder 2006',
#    'source': './data\\doc_CIS_URN_250903.pdf',
#    'author': '',
#    'modDate': "D:20080821135700+09'00'",
#    'trapped': '',
#    'file_path': './data\\doc_CIS_URN_250903.pdf',
#    'producer': 'ezPDF Builder 2006',
#    'keywords': ''},
#   ...]}

# %%
# 유사성 측정 : 에러 메세지 이유? (250605)

question = "CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)에 대한 이론 요약"
searchDocs = store_db_load.similarity_search(question, k=10)

print(searchDocs[0].page_content)
# Out:
# 24
# 1.3.2. DEMON을 이용한 ACIS 판정
#
#
# DEMON 분석은 표적의 수중방사소음(Underwater Radiated Noise; URN)
# 이 증폭되는 현상을 감지하여 추진기의 정보(날개 수, 회전 수)를 추정하
# 는 기법이다. DEMON 분석은 Detection of Envelope Modulation On Noise의
# 약자로 포락선(Envelope)를 이용한 소음신호 분석방법이다.
# 수중의 임의의 위치에서 계측한 음향 신호 𝑝(𝑡)는 주파수 및 시간에
# 대한 함수로 Equation 1-1과 같이 표현할 수 있다.
#
#
# 𝑝(𝑡) = ∑𝐴𝑖(𝑓𝑖, 𝑡)𝑒𝑗2𝜋𝑓𝑖𝑡
# ∞
# 𝑖=−∞
#
# (1-1)
#
# Equation 1-1과 같이 수중 음향 신호 𝑝(𝑡)는 무한한 주파수 신호들의 합의
# 형태로 표현된다. 여기서 𝐴𝑖(𝑓𝑖, 𝑡)는 각각의 주파수 신호들의 진폭을 의
# 미한다. 또한, 𝑝(𝑡)는 아래의 Equation 1-2와 같이 표현할 수 있다.

# %%
'''
InvalidArgumentError: Collection expecting embedding with dimension of 384, got 768
즉, ChromaDB에 저장된 벡터 차원(dimension)이 384인데, 현재 쿼리할 때 생성된 임베딩 벡터 크기가 768이라서 맞지 않아서 생기는 문제입니다.

왜 이런 문제가 생길까?
store_db_load라는 벡터스토어를 만들 때 특정 임베딩 모델을 사용했어요. (예: sentence-transformers/all-MiniLM-L6-v2 → 384차원)

그런데 지금 similarity_search 실행 시점에는 다른 임베딩 모델이 로드되어서 768차원 벡터를 만들고 있어요. (예: text-embedding-ada-002 → 1536차원, bge-base → 768차원 등)

즉, DB에 저장할 때 사용한 임베딩 모델과 검색할 때 사용한 임베딩 모델이 달라서 생긴 불일치 에러입니다.

'''

# %%
# retriever = db.as_retriever(search_kwargs={"k": 20})
retriever = store_db_load.as_retriever(search_kwargs={"k": 50})

# %% [markdown]
# #### llama 3 모델 이용

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_community.chat_models import ChatOllama

# Prompt 템플릿 생성
template = '''Answer the question based only on the following context:
{context} Please answer all the answers in Korean.:

Question: {question}
'''

prompt = ChatPromptTemplate.from_template(template)

def format_docs(docs):
    return '\n\n'.join([d.page_content for d in docs])

model = ChatOllama(model = "llama3")  

# RAG Chain 연결
rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# Chain 실행
query = "CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)에 대한 이론 요약"
answer = rag_chain.invoke(query)

print("Query:", query)
print("Answer:", answer)
# Out:
# C:\Users\wonta\AppData\Local\Temp\ipykernel_23536\2560697985.py:17: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   model = ChatOllama(model = "llama3")
# Query: CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)에 대한 이론 요약
# Answer: 캐비테이션 초생 선속(CIS, Cavitation Inception Speed)과 수중 방사 소음(URN, Underwater Radiated Noise)는 다음과 같은 이론적 요약을 갖는다.
#
# 캐비테이션 초생 선속(CIS)은 캐비테이션 초기 발생 상황부터 소음이 동반되며, 선속이 증가하면서 함께 증가한다. CIS는 추진기에서 매우 중요한 성능에 해당하는 성질로, 기포의 내파(Implosion) 특성시간은 몇 마이크로 초(Micro-second)에 이른다.
#
# 수중 방사 소음(URN)은 캐비테이션 초기 발생 상황부터 동반되는 소음으로, 추진기에서 캐비테이션이 발생하면 적함의 수동 음파탐지기(Sound Navigation and Ranging; SONAR)에 의해 위치가 노출될 수 있다. URN은 고주파수를 포함한 광대역(Broadband)의 특성을 갖는다.
#
# 따라서, CIS와 URN는 캐비테이션 초생 선속 해석과 관련된 이론적 요약을 갖는 것으로 볼 수 있다.

# %%
# 상용 LLM 서비스와 같이 pdf 파일을 요약하고 발표 자료(개조식) 형태롤 출력하는 것이 가능한가? (250905)
# 위와 같은 질문에 대하여 결과를 도출하는데 15분 소요

# %% [markdown]
# #### LM Studio : gemma-3-4b 사용 (250909)

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
# pip install langchain-openai


llm = ChatOpenAI(
    base_url="http://localhost:11434/v1",
    api_key="lm-studio",
    # model="lmstudio-community/Meta-Llama-3.1-8B-Instruct-GGUF",    # Llama 모델을 사용하는 경우 Google_API에서 반복 계속 (250821)
    # model = "lmstudio-community/gemma-2-2b-it-GGUF",
    model = "lmstudio-community/gemma-3-4b-it-GGUFF",
    # model = "mradermacher/kanana-nano-2.1b-base-GGUF",           # Llama 모델을 사용하는 경우와 동일, Google_API에서 반복 계속 (250821)
    temperature=0.2,
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()], # 스트림 출력 콜백
)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# Prompt 템플릿 생성
template = """
You are a summarization and presentation assistant.
Use ONLY the information in the context below: {context}
Output requirements:
Provide ONE short summary of the paper in Korean (no more than 5 sentences). 
Provide ONE presentation outline in Korean as a numbered list of slides. 
Do not repeat the summary or any slide.
Do not label slides as "Slide 1, Slide 2"; instead, just use numbers (1., 2., 3.).
End the answer with the token: <<END>>
Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

def format_docs(docs):
    return '\n\n'.join([d.page_content for d in docs])

# RAG Chain 연결
rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Chain 실행
# query = "CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)에 대한 발표 자료를 만들어주세요."
query = "Please summarize the paper and create presentation materials."

answer = rag_chain.invoke(query)

print("Query:", query)
print("Answer:", answer)
# Out:
# Query: Please summarize the paper and create presentation materials.
# Answer: Okay, here’s a summary of the paper in Korean, followed by a presentation outline as requested.
#
# **Summary (Korean):**
#
# 본 논문은 선박 추진기의 캐비테이션 초생 속도(CIS)를 예측하기 위한 전산유체역학(CFD) 해석 시스템 개발에 대해 다룬다.  날개 끝 보텍스 캐비테이션을 중심으로, 기포동역학적 모델링과 레이leigh-Plesset 방정식을 활용하여 CIS를 정확하게 예측하는 방법을 제시한다.  개발된 시스템은 다양한 수중 구조물에 대한 해석 결과를 통해 유효성을 검증했으며, 잠수함 추진기의 캐비테이션 초생 선속을 평가하는데 기여할 것으로 기대된다. 본 연구는 전산유체역학(CFD) 해석의 활용 가능성을 보여주는 중요한 사례이다.
#
# ---
#
# **Presentation Outline (Korean)**
#
# 1.  **서론:** 본 연구의 배경 및 목적 소개 - 캐비테이션 초생 선속의 중요성, 해군 함정 성능 개선을 위한 필요성
# 2.  **이론적 배경:** 캐비테이션 현상에 대한 이해 - 캐비테이션 정의, 발생 메커니즘 (Rayleigh-Plesset 방정식, 기포동역학)
# 3.  **전산유체역학 해석 시스템 구축:** 개발된 시스템의 구성 요소 및 특징 설명 - CFD 해석 방법론, 날개 끝 보텍스 캐비테이션 모델링
# 4.  **해석 결과 분석 및 검증:** 다양한 수중 구조물에 대한 해석 결과 제시 및 실험 데이터와의 비교 – DTMB 함정 적용 사례, 소음 예측 정확도 향상 효과
# 5.  **향후 연구 방향 제안:** 잠수함 추진기 캐비테이션 초생 선속 해석 시스템 고도화 및 해군 함정 성능 개선 방안 모색
#
# ---
#
# **Presentation Outline (Korean)**
#
# 1.  **서론 (Introduction):** 선박 추진기 캐비테이션 초생 선속의 중요성 및 연구 배경 설명
# 2.  **캐비테이션 현상 이론적 개요 (Theoretical Overview of Cavitation Phenomena):** 캐비테이션 발생 원리, Rayleigh-Plesset 방정식 등 핵심 개념 소개
# 3.  **전산유체역학(CFD) 해석 방법 (CFD Analysis Methodology):** 전산유체역학을 이용한 유동 해석의 기본 원리와 적용 방식 설명
# 4.  **본 연구 결과 (Results of This Study):** 타원형 날개에 대한 캐비테이션 초생 선속 해석 결과 및 검증 내용 요약
# 5.  본 연구는 캐비테이션 현상을 예측하기 위한 전산유체역학 해석 시스템 개발 및 유효성 검증을 수행했으며, 잠수함 추진기 캐비테이션 초생 선속 분석에 기여할 수 있는 기반 기술을 제시한다. 특히 날개 끝 보텍스 캐비테이션에 대한 연구를 통해 효율적인 해석 시스템 구축 가능성을 확인했다. 본 연구 결과는 해군 함정의 성능 개선 및 안전성 확보에 활용될 수 있을 것이다. 전산유체역학(CFD)을 기반으로 캐비테이션 초생 선속을 예측하는 기술 개발이 핵심 내용이다.
#
# Here’s a presentation outline in Korean:
#
# 1.  서론 (Introduction): 연구 배경 및 필요성, 본 논문의 목표 제시
# 2.  캐비테이션 현상 이론적 개요 (Theoretical Background of Cavitation): 캐비테이션의 정의, 발생 조건, Rayleigh-Plesset 방정식 소개
# 3.  전산유체역학(CFD) 해석 방법 (CFD Analysis Methodology): 전산유체역학의 기본 원리, 유동장 해석 기법 설명 (LES, DNS 등)
# 4.  본 연구 시스템 개발 (Development of the Developed System): 캐비테이션 초생 선속 해석 시스템 구축 과정 상세 기술
# 5.  실험 결과 및 검증 (Experimental Results and Validation): 타원형 날개에 대한 해석 결과를 실험 관측 결과와 비교하여 시스템의 유효성 검증
#
# ---
#
# **Presentation Outline:**
#
# 1.  **Introduction: Cavitation Inception Speed (CIS) – A Critical Ship Performance Factor** (Image: Schematic of cavitation bubble formation)
# 2.  **Background & Significance:** The importance of accurately predicting CIS for ship design and operational efficiency. Briefly discuss the impact of cavitation on hull integrity and noise levels.
# 3.  **Theoretical Framework: Bubble Dynamics & Rayleigh-Plesset Equation** (Diagram: Illustration of the Rayleigh-Plesset equation) – Explain the core principles behind the analysis, focusing on the key equations used to model bubble behavior.
# 4.  **Methodology - CFD Approach:** Overview of the computational fluid dynamics (CFD) approach employed in this research, including mesh generation and solver settings. Highlight the use of Q-criterion for vortex identification.
# 5.  **Validation & Results – Experimental Comparison**: Details on validating the CFD results against experimental data from Delen et al., demonstrating good agreement regarding free surface wave shapes and total resistance values.
# 6.  **Future Research Recommendations**: Suggestions for future research, including expanding the analysis to include more vessel types, incorporating noise prediction, and developing optimization tools for cavitation inception speed.
#
# ---
#
# Here’s a presentation outline in Korean:
#
# 1.  **Introduction (3 minutes)** – Background on cavitation and its importance in ship performance; overview of the paper's objectives.
# 2.  **Theoretical Framework (7 minutes)** – Explanation of bubble dynamics, Rayleigh-Plesset equation, and the key assumptions made in the analysis.
# 3.  **Methodology (8 minutes)** – Detailed description of the CFD simulation setup, mesh generation techniques (unstructured trimmed mesh, polyhedral mesh), and turbulence modeling approach (MRF).
# 4.  **Results & Validation (10 minutes)** – Presentation of the numerical results for the DTMB hull, comparison with Delen et al.’s experimental data, and discussion of validation findings regarding cavitation inception speed.
# 5.  – Discussion of future research directions including extending the analysis to various vessel types and integrating design optimization tools.
#
# Here’s a presentation outline in Korean:
#
# 1.  **Introduction & Background:** (Briefly introduce cavitation and its importance in ship performance, mentioning the research focus on cavitation inception speed prediction.)
# 2.  **Theoretical Framework:** (Explain the key equations used – Navier-Stokes, Rayleigh-Plesset – and the methodology of bubble dynamics analysis.)
# 3.  **Numerical Simulation Methodology:** (Detail the CFD approach, including mesh generation techniques like unstructured trimmed grid and MRF for rotating domains, highlighting the validation process against experimental data.)
# 4.  **Results & Analysis:** (Present key findings from simulations on various hull shapes, comparing with Delen et al.’s results and showcasing the impact of parameters like speed and resistance.)
# 5.  (The paper investigates cavitation inception speed prediction using CFD, developing a system based on bubble dynamics and Rayleigh-Plesset equations to analyze noise generation around submerged structures, suggesting further research into optimizing hull designs for reduced cavitation.)
#
# Here’s a presentation outline in Korean:
#
# 1.  **서론 (Introduction)** - 캐비테이션 현상의 중요성 및 연구 배경 설명
# 2.  **이론적 배경 (Theoretical Background)** - 전산유체역학(CFD)의 기본 원리, 유동 방정식 소개
# 3.  **캐비테이션 초생 선속 해석 시스템 개발 (Development of Cavitation Inception Speed Analysis System)** - 핵심 기술 및 시스템 구성 설명
# 4.  **실험 결과 분석 (Analysis of Experimental Results)** - 타원형 날개에 대한 해석 결과 제시 및 검증
# 5.  **결론 및 향후 연구 방향 (Conclusion and Future Research Directions)** - 연구의 의의와 추가 연구 제안
#
# ---
#
# Here’s a presentation outline in Korean:
#
# 1.  서론: 캐비테이션 초생 선속의 중요성 및 연구 배경 설명
# 2.  이론적 기초: 기포동역학, 레이leigh 방정식, 난류 해석 등 핵심 이론 소개
# 3.  전산유체역학 해석 방법: CFD 모델링, 격자 생성, 수치해석 과정 상세 설명
# 4.  실험 결과 분석: 타원형 날개 캐비테이션 초생 선속 해석 결과 제시 및 Delen et al. 연구와의 비교 분석
# 5.  결론 및 향후 연구 방향: 시스템 검증, 잠수함 추진기 설계 적용 등 추가 연구 제안
#
# <<END>>

# %%
# LM Studio > Load > Context Length : 10200으로 설정 -> 에러 메세지 확인 후, 좀 더 큰 값으로 입력할 것(250910)
# Step 1에서 무한 반복 문제점 발생 (250910)

# %%
# 템플릿 옵션 변경 #3

from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# Prompt 템플릿 생성
template = """
You must answer using ONLY the information in the context below. 
Do NOT use any outside knowledge.

Context:
{context}

Task:
1) Create a presentation outline in Korean for PPT slides. 
   - Each slide must include: 
     • Title 
     • 3–4 bullet points 
     • 1–2 sentence speaker note
2) Produce each part exactly ONCE and do not repeat.
3) End your answer with the token: <<END>>

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

def format_docs(docs):
    return '\n\n'.join([d.page_content for d in docs])

# RAG Chain 연결
rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Chain 실행
# query = "CIS(캐비테이션 초생 선속)와 URN(수중 방사 소음)에 대한 발표 자료를 만들어주세요."
query = "Please create presentation materials."

answer = rag_chain.invoke(query)

print("Query:", query)
print("Answer:", answer)
# Out:
# Query: Please create presentation materials.
# Answer: Okay, here’s a detailed presentation outline in Korean for PPT slides focusing on the provided context (cavitation inception analysis), following your instructions.
#
# **Presentation Outline – 캐비테이션 초생 선속 분석 (Cavitation Inception Speed Analysis)**
#
# **(Slide 1: Title Slide)**
#
# *   Title: 캐비테이션 초생 선속 분석 및 시스템 개발 (Analysis and System Development of Cavitation Inception Speed)
# *   Bullet Points:
#     • 연구 목표 제시 (Presentation of Research Objectives)
#     • 핵심 기술 소개 (Introduction of Core Technologies)
#     • 결과 요약 (Summary of Results)
# *   Speaker Note: “본 발표에서는 선박 추진기의 캐비테이션 초생 선속을 예측하기 위한 새로운 분석 시스템 개발에 대해 설명합니다.  이 시스템은 기포동역학적 모델링과 전산 유체 역학(CFD) 기술을 통합하여 활용됩니다.”
#
# **(Slide 2: Cavitation Overview – 캐비테이션 개요)**
#
# *   Title: 캐비테이션 현상 이해 (Understanding the Cavitation Phenomenon)
# *   Bullet Points:
#     • 캐비테이션 정의 (Definition of Cavitation)
#     • 캐비테이션 유형 분류 (Classification of Cavitation Types - 이동, 고정, 진동)
#     • 캐비테이션 발생 요인 (Factors Contributing to Cavitation Formation – Reynolds 수, 유속 등)
# *   Speaker Note: “캐비테이션은 유체 흐름에서 발생하는 현상으로, 액체가 기체로 갑작스럽게 변하는 현상을 말합니다.  이러한 현상은 선박 추진기의 성능 저하 및 손상 원인이 됩니다.”
#
# **(Slide 3: Methodology – 방법론)**
#
# *   Title: 분석 시스템의 구성 (Composition of the Analysis System)
# *   Bullet Points:
#     • 기포동역학 모델링 (Bubble Dynamics Modeling - Rayleigh-Plesset 방정식 활용)
#     • 전산 유체 역학(CFD) 시뮬레이션 (Computational Fluid Dynamics Simulation – Q-criterion 적용)
#     • 소음 해석 (Noise Analysis – 단극자 소음원 모델링)
# *   Speaker Note: “본 연구에서는 기포동역학적 모델링과 CFD 시뮬레이션을 결합하여 캐비테이션 초생 선속을 정확하게 예측합니다. 특히, Q-criterion을 사용하여 와류를 효과적으로 분석합니다.”
#
# **(Slide 4: 타원형날개 해석 결과 – Elliptical Wing Analysis Results)**
#
# *   Title: 간단한 형상에서의 시스템 검증 (System Validation on Simple Shape)
# *   Bullet Points:
#     • 타원형날개 모델링 (Modeling of Elliptical Wing)
#     • CIS 예측 결과 제시 (Presentation of CIS Prediction Results)
#     • 실험 결과와의 비교 (Comparison with Experimental Results – Carlton, 2018 기준)
# *   Speaker Note: “타원형날개를 사용하여 개발한 시스템의 유효성을 검증했습니다.  이 결과는 실제 추진기 캐비테이션 현상을 예측하는 데 활용될 수 있습니다.”
#
# **(Slide 5: 추진기 CIS 해석 – Propulsion System CIS Analysis)**
#
# *   Title: 잠수함/수상함 추진기에 적용 (Application to Submarine/Surface Ship Propellers)
# *   Bullet Points:
#     • 다양한 추진기 형상 분석 (Analysis of Various Propeller Geometries)
#     • CIS 예측 및 비교 (Prediction and Comparison of CIS)
#     • 설계 최적화 가능성 제시 (Suggestion for Design Optimization)
# *   Speaker Note: “본 연구에서 개발한 시스템은 잠수함 및 수상함 추진기의 캐비테이션 초생 선속을 예측하고, 이를 기반으로 추진기 설계를 최적화하는 데 기여할 수 있습니다.”
#
# **(Slide 6: 향후 연구 방향 – Future Research Directions)**
#
# *   Title: 추가 연구 및 개발 계획 (Additional Research and Development Plans)
# *   Bullet Points:
#     • 고정밀 시뮬레이션 시스템 구축 (Construction of High-Precision Simulation System)
#     • 와류 발생기 설계 최적화 (Optimization of Vortex Generator Design)
#     • 다양한 해양 환경 조건 적용 (Application to Various Marine Environment Conditions)
# *   Speaker Note: “향후 연구에서는 더욱 정교한 시뮬레이션 시스템을 구축하고, 와류 발생기를 통해 캐비테이션 초생 선속을 지연시키는 기술 개발에 집중할 계획입니다.”
#
# **(Slide 7: Conclusion – 결론)**
#
# *   Title: 결론 (Conclusion)
# *   Bullet Points:
#     • 새로운 분석 시스템의 성공적인 개발 (Successful Development of New Analysis System)
#     • 해군 함정 추진기 성능 향상 기여 (Contribution to Improving Propulsion Performance of Naval Vessels)
#     • 지속적인 연구 개발 필요성 강조 (Emphasis on the Need for Continued Research and Development)
# *   Speaker Note: “본 연구를 통해 선박 추진기의 캐비테이션 초생 선속을 예측하는 새로운 시스템이 개발되었으며, 이는 해군 함정의 성능 향상에 크게 기여할 것으로 기대됩니다.”
#
# <<END>>

# %%
# LM Studio > Load > Context Length : 10300으로 설정 -> 에러 메세지 확인 후, 좀 더 큰 값으로 입력할 것(250910)
# Step 1에서 무한 반복을 해결하기 위해 템플릿 수정 (250910)

# 실제 논문의 제목과 LLM 이 도출한 발표자료의 제목이 다른 점을 주목하자 (250910)
